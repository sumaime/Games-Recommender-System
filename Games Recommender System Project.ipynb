# %% [markdown]
# # Games Recommender System
#
# This is a recommender system based on Stream user information. We need to extract all data needed from steamAPI and then build models to find the appropriate games to recommend.

# %%
import requests, json, os, sys, time, re
from datetime import datetime
from multiprocessing import Pool # multiprocess function for each worker using
import requests
from bs4 import BeautifulSoup
import math
import pandas as pd
import pymysql
import sqlalchemy
import string
from sklearn.feature_extraction.text import TfidfVectorizer # Process text infomation
from sklearn.metrics.pairwise import linear_kernel,cosine_similarity # Calculate the similar users or products
import numpy as np

# %%
# Loading bar
def show_work_status(singleCount, totalCount, currentCount=0):
    currentCount += singleCount
    percentage = 1. * currentCount / totalCount * 100
    status =  '>' * int(percentage)  + ' ' * (100 - int(percentage))
    sys.stdout.write('\rStatus: [{0}] {1:.2f}% '.format(status, percentage))
    sys.stdout.flush()
    if percentage >= 100:
        print ('\n')

# Split a long list into n short lists
def split_list(lst_long,n):
    lst_splitted = []
    if len(lst_long) % n == 0:
        totalBatches = math.floor(len(lst_long) / n)
    else:
        totalBatches = math.floor(len(lst_user_id) / n + 1)
    for i in range(totalBatches):
        lst_short = lst_long[i*n:(i+1)*n]
        lst_splitted.append(lst_short)
    return lst_splitted

# %% [markdown]
# ## Data ETL

# %% [markdown]
# #### 1. Crawl users' inventory
# Crawling user infomation by user id and store it into txt file(user_inventory)
#
# GetOwnedGames (v0001):
#
# GetOwnedGames returns a list of games a player owns along with some playtime information, if the profile is publicly visible. Private, friends-only, and other privacy settings are not supported unless you are asking for your own personal details (ie the WebAPI key you are using is linked to the steamid you are requesting).
#
# https://developer.valvesoftware.com/wiki/Steam_Web_API#GetOwnedGames_.28v0001.29

# %%
# Read the user id in txt file
path_user_id = 'data/steam_user_id.txt'
# Open txt file and read binary since the id is effective for every 2 lines
with open(path_user_id, 'rb') as f:
#     Eliminate n/t/ at the end of every id
#     Read first 50
    lst_user_id = [x.strip() for x in f.readlines()]

# %%
len(lst_user_id)
# Out:
# 5000

# %%
def worker(lst_user_id_temp):
#     Empty dict for store id:contents
    dic_temp = {}
    for user_id in lst_user_id_temp[0:len(lst_user_id_temp)]:
#         API website
        base_url = "http://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/"
#         Keys API requred
        params = {
            'key' : 'D4BA51BB9B8BEF48E66C731BB70B7BCF',
            'steamid' : user_id.strip(),
            'format' : 'json' }
        r = requests.get(base_url, params = params)
#         Get games information 
        user_inventory = r.json(encoding = 'utf-8').get('response').get('games')
#         Update dictionary for contents scraped using id
        dic_temp.update({user_id:user_inventory})
#         Sleep 0.5 second to avoid causing stress for the website
        time.sleep(.5)
    return dic_temp

# %%
# 2 Pools for 50 id means 2 workers process 50 ids seperately, each handles 25 ids.
p = Pool(2)

# Parameter for loading par
total_count = len(lst_user_id)
current_count = 0
show_work_status(0, total_count, current_count)

# Creat master dict to combine the total works handled by 2 pools
dic_master = {}
# Process a batch(500 ids) every time
for i in split_list(lst_user_id,10):
#   2 workers works on 1/2 batch(100 ids) each time
    lst_temp_dic = p.map(worker, split_list(i,5))
#   Update dic_master after getting the id and its content
    for j in lst_temp_dic:
        dic_master.update(j)
#   Show the work status for every batch processed
    show_work_status(len(i), total_count, current_count)
    current_count += len(i)
#   In case of causing stress to website
    time.sleep(0.5)
# Out:
# Status: [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 100.00%
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/anaconda/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/anaconda/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/anaconda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/anaconda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/anaconda/lib/python3.6/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/anaconda/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/anaconda/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/anaconda/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/anaconda/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/anaconda/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt

# %%
# Store user info into crawled_user_inventory
with open('data/user_inventory.txt', 'w') as f:
    for user_id, user_inventory in list(dic_master.items()):
        f.write(json.dumps({str(user_id):user_inventory}))
        f.write('\n')

# %% [markdown]
# #### 2.1 Get app ID
#
# Get all app's information(id, price, userscore...) from steam API, 64342 app ids in total.

# %%
# Get all app's ID from steam

url_app = 'http://api.steampowered.com/ISteamApps/GetAppList/v2/'
r = requests.get(url_app)
dic_app_list = r.json()
lst_app_id = [i.get('appid') for i in dic_app_list.get('applist').get('apps')]

# %%
len(lst_app_id)
# Out:
# 66424

# %%
lst_app_id[0:5]
# Out:
# [5, 7, 8, 10, 20]

# %% [markdown]
# #### 2.2 Scrape the all app information using app ID
#
# Store the information into path_app_detail.

# %%
total_count = len(lst_app_id)#lst_app_id)
current_count = 0
show_work_status(0, total_count, current_count)

# Create text file for all app detailed information.
path_app_detail = 'data/path_app_detail.txt'

# Prepare file to be written
with open(path_app_detail, 'w') as f:
    for app_id in lst_app_id:
 
        url_app_detail = ('http://store.steampowered.com/api/appdetails?appids=%s') % (app_id) # Scrape using appID
        
        # Get the app detail and transfer to json format, if the app ID is not readable through api website, pass it
        for i in range(2):
            try:
                r = requests.get(url_app_detail)
                result = r.json()
                break
            except:
                time.sleep(5)
                pass
        f.write(json.dumps(result))
        f.write('\n')
        show_work_status(1, total_count, current_count)
        current_count += 1
        if current_count % 200 == 0:
            time.sleep(2.5)
        else:
            time.sleep(.5)
# Out:
# Status: [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 100.00%

# %% [markdown]
# Extract the detailed game information and the description of game

# %%
# Open and read the scraped app information
with open(path_app_detail, 'r') as f:
#     Create dic store information for each app id
    dic_steam_app = {'initial_price':{},'name':{},'score':{},'windows':{},'mac':{},'linux':{},'type':{},'release_date':{},'recommendation':{},'header_image':{}}
    dic_about_the_game = {}
#     Read txt file into lst_raw_string
    lst_raw_string = f.readlines()
#     Set counts for statue bar
    total_count = len(lst_raw_string)
    current_count = 0
    show_work_status(0, total_count, current_count)
    
#     release_date = ''
#     Read each item in the list of app information
    for raw_string in lst_raw_string:
        try:
#           Only one item in the list, extract the item from the list
            app_data = list(json.loads(raw_string).values())[0]
        except:
            pass
        
        if app_data != {} and app_data.get('success') != False: # If app_data is not empty

#           Get needed information from app_data
            steam_id = app_data.get('data').get('steam_appid') # Get game id
            initial_price = app_data.get('data').get('price_overview',{}).get('initial')
            if app_data.get('data').get('is_free') == True: # Get price
                initial_price = 0
                
            app_name = app_data.get('data').get('name') # Get game name
            
            critic_score = app_data.get('data').get('metacritic',{}).get('score') # Get score
            
            app_type = app_data.get('data').get('type') # Get game type
            
            for (platform, is_supported) in app_data.get('data').get('platforms',{}).items():
                if is_supported == True: # Get platform game runs on
                    dic_steam_app[platform].update({steam_id:1})
            
            if app_data.get('data').get('release_date',{}).get('coming_soon') == False: # Get date
                release_date = app_data.get('data').get('release_date',{}).get('date')
                if not release_date == '':
                    try:
                        release_date = datetime.strptime(release_date, '%b %d, %Y')
                    except:
                        try:
                            release_date = datetime.strptime(release_date, '%d %b, %Y')
                        except:
                            release_date = None
            
            about_the_game = app_data.get('data').get('about_the_game')# Get game description
            soup = BeautifulSoup(about_the_game,'lxml') # Tranfer text to lxml to remove lxml format in text
            game_description = re.sub(r'(\s+)',' ',soup.text).strip() # re.sub(pattern, repl, string) Reduce \t,\n
            dic_about_the_game.update({steam_id:game_description})
            
            recommendation = app_data.get('data').get('recommendations',{}).get('total') # Get recommendation
            header_image = app_data.get('data').get('header_image') # Get path of header image
            dic_steam_app['recommendation'].update({steam_id:recommendation})
            dic_steam_app['header_image'].update({steam_id:header_image})
            
            dic_steam_app['initial_price'].update({steam_id:initial_price})
            dic_steam_app['name'].update({steam_id:app_name})
            dic_steam_app['score'].update({steam_id:critic_score})
            dic_steam_app['type'].update({steam_id:app_type})
            dic_steam_app['release_date'].update({steam_id:release_date})

            

                
        show_work_status(1, total_count, current_count)
        current_count += 1
# Out:
# Status: [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 100.00%

# %%
dic_about_the_game[10]
# Out:
# "Play the world's number 1 online action game. Engage in an incredibly realistic brand of terrorist warfare in this wildly popular team-based game. Ally with teammates to complete strategic missions. Take out enemy sites. Rescue hostages. Your role affects your team's success. Your team's success affects your role."

# %%
dic_steam_app
# Out:
# {'header_image': {10: 'https://steamcdn-a.akamaihd.net/steam/apps/10/header.jpg?t=1528733245',
#   20: 'https://steamcdn-a.akamaihd.net/steam/apps/20/header.jpg?t=1528732825',
#   30: 'https://steamcdn-a.akamaihd.net/steam/apps/30/header.jpg?t=1512413490',
#   40: 'https://steamcdn-a.akamaihd.net/steam/apps/40/header.jpg?t=1528733362',
#   50: 'https://steamcdn-a.akamaihd.net/steam/apps/50/header.jpg?t=1530046417',
#   60: 'https://steamcdn-a.akamaihd.net/steam/apps/60/header.jpg?t=1528733092',
#   70: 'https://steamcdn-a.akamaihd.net/steam/apps/70/header.jpg?t=1530045175',
#   80: 'https://steamcdn-a.akamaihd.net/steam/apps/80/header.jpg?t=1512411962',
#   92: 'https://steamcdn-a.akamaihd.net/steam/apps/92/header.jpg?t=1447350816',
#   130: 'https://steamcdn-a.akamaihd.net/steam/apps/130/header.jpg?t=1530045564',
#   150: 'https://steamcdn-a.akamaihd.net/steam/apps/150/header.jpg?t=1447353168',
#   219: 'https://steamcdn-a.akamaihd.net/steam/apps/219/header.jpg?t=1447350816',
#   220: 'https://steamcdn-a.akamaihd.net/steam/apps/220/header.jpg?t=1533329234',
#   240: 'https://steamcdn-a.akamaihd.net/steam/apps/240/header.jpg?t=1515613564',
#   280: 'https://steamcdn-a.akamaihd.net/steam/apps/280/header.jpg?t=1530046549',
#   300: 'https://steamcdn-a.akamaihd.net/steam/apps/300/header.jpg?t=1512413758',
#   320: 'https://steamcdn-a.akamaihd.net/steam/apps/320/header.jpg?t=1512752170',
#   340: 'https://steamcdn-a.akamaihd.net/steam/apps/340/header.jpg?t=1530046348',
#   360: 'https://steamcdn-a.akamaihd.net/steam/apps/360/header.jpg?t=1530046445',
#   380: 'https://steamcdn-a.akamaihd.net/steam/apps/380/header.jpg?t=1530046506',
#   400: 'https://steamcdn-a.akamaihd.net/steam/apps/400/header.jpg?t=1512752294',
#   410: 'https://steamcdn-a.akamaihd.net/steam/apps/410/header.jpg?t=1447351220',
#   420: 'https://steamcdn-a.akamaihd.net/steam/apps/420/header.jpg?t=1530046627',
#   440: 'https://steamcdn-a.akamaihd.net/steam/apps/440/header.jpg?t=1519430091',
#   500: 'https://steamcdn-a.akamaihd.net/steam/apps/500/header.jpg?t=1517005754',
#   550: 'https://steamcdn-a.akamaihd.net/steam/apps/550/header.jpg?t=1527191338',
#   570: 'https://steamcdn-a.akamaihd.net/steam/apps/570/header.jpg?t=1534807984',
#   620: 'https://steamcdn-a.akamaihd.net/steam/apps/620/header.jpg?t=1512411524',
#   630: 'https://steamcdn-a.akamaihd.net/steam/apps/630/header.jpg?t=1447353182',
#   660: 'https://steamcdn-a.akamaihd.net/steam/apps/660/header.jpg?t=1447354286',
#   730: 'https://steamcdn-a.akamaihd.net/steam/apps/730/header.jpg?t=1535671596',
#   900: 'https://steamcdn-a.akamaihd.net/steam/apps/900/header.jpg?t=1447350835',
#   901: 'https://steamcdn-a.akamaihd.net/steam/apps/300/header.jpg?t=1512413758',
#   902: 'https://steamcdn-a.akamaihd.net/steam/apps/1600/header.jpg?t=1447350835',
#   904: 'https://steamcdn-a.akamaihd.net/steam/apps/220/header.jpg?t=1533329234',
#   905: 'https://steamcdn-a.akamaihd.net/steam/apps/380/header.jpg?t=1530046506',
#   906: 'https://steamcdn-a.akamaihd.net/steam/apps/1002/header.jpg?t=1447350828',
#   907: 'https://steamcdn-a.akamaihd.net/steam/apps/1200/header.jpg?t=1447350836',
#   908: 'https://steamcdn-a.akamaihd.net/steam/apps/2500/header.jpg?t=1476272970',
#   909: 'https://steamcdn-a.akamaihd.net/steam/apps/1300/header.jpg?t=1464638889',
#   912: 'https://steamcdn-a.akamaihd.net/steam/apps/380/header.jpg?t=1530046506',
#   913: 'https://steamcdn-a.akamaihd.net/steam/apps/380/header.jpg?t=1530046506',
#   914: 'https://steamcdn-a.akamaihd.net/steam/apps/380/header.jpg?t=1530046506',
#   915: 'https://steamcdn-a.akamaihd.net/steam/apps/380/header.jpg?t=1530046506',
#   916: 'https://steamcdn-a.akamaihd.net/steam/apps/420/header.jpg?t=1530046627',
#   917: 'https://steamcdn-a.akamaihd.net/steam/apps/300/header.jpg?t=1512413758',
#   918: 'https://steamcdn-a.akamaihd.net/steam/apps/300/header.jpg?t=1512413758',
#   919: 'https://steamcdn-a.akamaihd.net/steam/apps/2100/header.jpg?t=1447350903',
#   920: 'https://steamcdn-a.akamaihd.net/steam/apps/2100/header.jpg?t=1447350903',
#   921: 'https://steamcdn-a.akamaihd.net/steam/apps/2100/header.jpg?t=1447350903',
#   922: 'https://steamcdn-a.akamaihd.net/steam/apps/400/header.jpg?t=1512752294',
#   923: 'https://steamcdn-a.akamaihd.net/steam/apps/440/header.jpg?t=1519430091',
#   924: 'https://steamcdn-a.akamaihd.net/steam/apps/1200/header.jpg?t=1447350836',
#   925: 'https://steamcdn-a.akamaihd.net/steam/apps/1200/header.jpg?t=1447350836',
#   926: 'https://steamcdn-a.akamaihd.net/steam/apps/1200/header.jpg?t=1447350836',
#   927: 'https://steamcdn-a.akamaihd.net/steam/apps/3000/header.jpg?t=0',
#   929: 'https://steamcdn-a.akamaihd.net/steam/apps/1510/header.jpg?t=1478098895',
#   930: 'https://steamcdn-a.akamaihd.net/steam/apps/420/header.jpg?t=1530046627',
#   931: 'https://steamcdn-a.akamaihd.net/steam/apps/440/header.jpg?t=1519430091',
#   932: 'https://steamcdn-a.akamaihd.net/steam/apps/420/header.jpg?t=1530046627',
#   933: 'https://steamcdn-a.akamaihd.net/steam/apps/420/header.jpg?t=1530046627',
#   934: 'https://steamcdn-a.akamaihd.net/steam/apps/420/header.jpg?t=1530046627',
#   936: 'https://steamcdn-a.akamaihd.net/steam/apps/420/header.jpg?t=1530046627',
#   937: 'https://steamcdn-a.akamaihd.net/steam/apps/420/header.jpg?t=1530046627',
#   940: 'https://steamcdn-a.akamaihd.net/steam/apps/2100/header.jpg?t=1447350903',
#   941: 'https://steamcdn-a.akamaihd.net/steam/apps/1200/header.jpg?t=1447350836',
#
#   5446: 'https://steamcdn-a.akamaihd.net/steam/apps/17450/header.jpg?t=1447351620',
#   5447: 'https://steamcdn-a.akamaihd.net/steam/apps/17450/header.jpg?t=1447351620',
#   5449: 'https://steamcdn-a.akamaihd.net/steam/apps/17450/header.jpg?t=1447351620',
#   5451: 'https://steamcdn-a.akamaihd.net/steam/apps/17450/header.jpg?t=1447351620',
#   5453: 'https://steamcdn-a.akamaihd.net/steam/apps/40400/header.jpg?t=1524670300',
#   5455: 'https://steamcdn-a.akamaihd.net/steam/apps/34650/header.jpg?t=0',
#   5456: 'https://steamcdn-a.akamaihd.net/steam/apps/34640/header.jpg?t=1478096939',
#   5459: 'https://steamcdn-a.akamaihd.net/steam/apps/27400/header.jpg?t=1447351701',
#   5505: 'https://steamcdn-a.akamaihd.net/steam/apps/40400/header.jpg?t=1524670300',
#   5507: 'https://steamcdn-a.akamaihd.net/steam/apps/11170/header.jpg?t=0',
#   5513: 'https://steamcdn-a.akamaihd.net/steam/apps/9900/header.jpg?t=1531328622',
#   5514: 'https://steamcdn-a.akamaihd.net/steam/apps/41000/header.jpg?t=1478160462',
#   5515: 'https://steamcdn-a.akamaihd.net/steam/apps/8980/header.jpg?t=1531778995',
#   5518: 'https://steamcdn-a.akamaihd.net/steam/apps/24980/header.jpg?t=1447352739',
#   5521: 'https://steamcdn-a.akamaihd.net/steam/apps/10690/header.jpg?t=1447351828',
#   5522: 'https://steamcdn-a.akamaihd.net/steam/apps/22370/header.jpg?t=1449019604',
#   5523: 'https://steamcdn-a.akamaihd.net/steam/apps/22370/header.jpg?t=1449019604',
#   5524: 'https://steamcdn-a.akamaihd.net/steam/apps/22370/header.jpg?t=1449019604',
#   5525: 'https://steamcdn-a.akamaihd.net/steam/apps/22370/header.jpg?t=1449019604',
#   5526: 'https://steamcdn-a.akamaihd.net/steam/apps/22370/header.jpg?t=1449019604',
#   5529: 'https://steamcdn-a.akamaihd.net/steam/apps/24180/header.jpg?t=0',
#   5530: 'https://steamcdn-a.akamaihd.net/steam/apps/13140/header.jpg?t=1489513231',
#   5531: 'https://steamcdn-a.akamaihd.net/steam/apps/13140/header.jpg?t=1489513231',
#   5532: 'https://steamcdn-a.akamaihd.net/steam/apps/13140/header.jpg?t=1489513231',
#   5533: 'https://steamcdn-a.akamaihd.net/steam/apps/13140/header.jpg?t=1489513231',
#   5534: 'https://steamcdn-a.akamaihd.net/steam/apps/13140/header.jpg?t=1489513231',
#   5535: 'https://steamcdn-a.akamaihd.net/steam/apps/8190/header.jpg?t=1530644128',
#   5536: 'https://steamcdn-a.akamaihd.net/steam/apps/5536/header.psd?t=1531432804',
#   5537: 'https://steamcdn-a.akamaihd.net/steam/apps/5537/header.jpg?t=1447352782',
#   5539: 'https://steamcdn-a.akamaihd.net/steam/apps/5539/header.jpg?t=1447352794',
#   5541: 'https://steamcdn-a.akamaihd.net/steam/apps/18820/header.jpg?t=1447352797',
#   5544: 'https://steamcdn-a.akamaihd.net/steam/apps/36000/header.jpg?t=1447352370',
#   5546: 'https://steamcdn-a.akamaihd.net/steam/apps/5546/header.jpg?t=1447352815',
#   5547: 'https://steamcdn-a.akamaihd.net/steam/apps/5547/header.jpg?t=1447352815',
# ...
#   5791: 'movie',
#   5793: 'movie',
#   5794: 'movie',
#   5795: 'movie',
#   5796: 'movie',
#   5797: 'movie',
#   5798: 'movie',
#   5799: 'movie',
#   5801: 'movie',
#   5802: 'movie',
#   5803: 'movie',
#   5804: 'movie',
#   5805: 'movie',
#   5806: 'movie',
#   5807: 'movie',
#   5808: 'movie',
#   5809: 'movie',
#   5811: 'movie',
#   5812: 'movie',
#   5813: 'movie',
#   5814: 'movie',
#   5815: 'movie',
#   5817: 'movie',
#   5818: 'movie',
#   5819: 'movie',
#   5820: 'movie',
#   5822: 'movie',
#   5823: 'movie',
#   5824: 'movie',
#   5825: 'movie',
#   5829: 'movie',
#   5830: 'movie',
#   5831: 'movie',
#   5833: 'movie',
#   5837: 'movie',
#   5838: 'movie',
#   5839: 'movie',
#   5841: 'movie',
#   5842: 'movie',
#   5844: 'movie',
#   5852: 'movie',
#   5855: 'movie',
#   5856: 'movie',
#   5857: 'movie',
#   5858: 'movie',
#   5859: 'movie',
#   5860: 'movie',
#   5861: 'movie',
#   5864: 'movie',
#   5865: 'movie',
#   5866: 'movie',
#   5867: 'movie',
#   5869: 'movie',
#   5870: 'movie',
#   5872: 'movie',
#   5874: 'movie',
#   5877: 'movie',
#   5878: 'movie',
#   5879: 'movie',
#   5882: 'movie',
#   5883: 'movie',
#   5885: 'movie',
#   5887: 'movie',
#   5888: 'movie',
#   5889: 'movie',
#   5896: 'movie',
#   5897: 'movie',
#   5899: 'movie',
#   5901: 'movie',
#   5902: 'movie',
#   5903: 'movie',
#   5904: 'movie',
#   5905: 'movie',
#   5906: 'movie',
#   5908: 'movie',
#   5909: 'movie',
#   5910: 'movie',
#   5911: 'movie',
#   5912: 'movie',
#   5913: 'movie',
#   5914: 'movie',
#   5915: 'movie',
#   5916: 'movie',
#   5918: 'movie',
#   5922: 'movie',
#   5926: 'movie',
#   5927: 'movie',
#   5928: 'movie',
#   5929: 'movie',
#   5931: 'movie',
#   5932: 'movie',
#   5933: 'movie',
#   5939: 'movie',
#   5940: 'movie',
#   5941: 'movie',
#   5942: 'movie',
#   5945: 'movie',
#   5946: 'movie',
#   5949: 'movie',
#   5950: 'movie',
#   5951: 'movie',
#   5952: 'movie',
#   5956: 'movie',
#   5958: 'movie',
#   5959: 'movie',
#   5960: 'movie',
#   5968: 'movie',
#   6230: 'demo',
#   6250: 'game',
#   6260: 'demo',
#   6270: 'game',
#   6290: 'advertising',
#   6300: 'game',
#   6310: 'game',
#   6320: 'demo',
#   6370: 'game',
#   6400: 'game',
#   6410: 'demo',
#   6420: 'game',
#   6510: 'game',
#   6550: 'game',
#   6580: 'demo',
#   6600: 'game',
#   6800: 'game',
#   6810: 'game',
#   6830: 'game',
#   6840: 'game',
#   6850: 'game',
#   6860: 'game',
#   6870: 'game',
#   6880: 'game',
#   6900: 'game',
#   6910: 'game',
#   6920: 'game',
#   6930: 'demo',
#   6940: 'demo',
#   6950: 'demo',
#   6980: 'game',
#   7000: 'game',
#   7010: 'game',
#   7020: 'game',
#   7030: 'demo',
#   7050: 'demo',
#   7110: 'game',
#   7200: 'game',
#   7210: 'game',
#   7220: 'game',
#   7230: 'demo',
#   7260: 'game',
#   7280: 'demo',
#   7290: 'demo',
#   7340: 'game',
#   7400: 'advertising',
#   7420: 'advertising',
#   7440: 'advertising',
#   7450: 'advertising',
#   7470: 'advertising',
#   7510: 'game',
#   7520: 'game',
#   7530: 'game',
#   7600: 'game',
#   7610: 'game',
#   7620: 'game',
#   7650: 'game',
#   7660: 'game',
#   7670: 'game',
#   7710: 'demo',
#   7730: 'game',
#   7740: 'advertising',
#   7760: 'game',
#   7770: 'game',
#   7780: 'advertising',
#   7800: 'advertising',
#   7810: 'advertising',
#   7830: 'game',
#   7840: 'game',
#   7860: 'game',
#   7880: 'advertising',
#   7890: 'demo',
#   7900: 'advertising',
#   7910: 'advertising',
#   7940: 'game',
#   7980: 'advertising',
#   7990: 'advertising',
#   8000: 'game',
#   8010: 'advertising',
#   8030: 'demo',
#   8080: 'game',
#   8090: 'demo',
#   8100: 'game',
#   8140: 'game',
#   8150: 'demo',
#   8170: 'game',
#   8180: 'demo',
#   8190: 'game',
#   8200: 'game',
#   8210: 'game',
#   8220: 'game',
#   8230: 'game',
#   8240: 'game',
#   8250: 'game',
#   8260: 'game',
#   8270: 'game',
#   8280: 'game',
#   8290: 'game',
#   8300: 'game',
#   8310: 'game',
#   8320: 'game',
#   8330: 'game',
#   8340: 'game',
#   8350: 'game',
#   8360: 'game',
#   8370: 'game',
#   8380: 'game',
#   8400: 'game',
#   8500: 'game',
#   8600: 'game',
#   8780: 'game',
#   8650: 'dlc',
#   8660: 'dlc',
#   8690: 'dlc',
#   8700: 'demo',
#   8720: 'demo',
#   8750: 'advertising',
#   8760: 'demo',
#   8790: 'game',
#   8800: 'game',
#   8820: 'demo',
#   8830: 'advertising',
#   8850: 'game',
#   8870: 'game',
#   8880: 'game',
#   8890: 'game',
#   8900: 'demo',
#   8910: 'demo',
#   8930: 'game',
#   8970: 'game',
#   8980: 'game',
#   8990: 'dlc',
#   9000: 'game',
#   9010: 'game',
#   9030: 'game',
#   9040: 'game',
#   9050: 'game',
#   9060: 'game',
#   9070: 'dlc',
#   9080: 'demo',
#   9090: 'demo',
#   9940: 'game',
#   9950: 'demo',
#   9960: 'game',
#   9970: 'game',
#   9980: 'game',
#   9992: 'dlc',
#   9998: 'demo',
#   10040: 'advertising',
#   10080: 'advertising',
#   10090: 'game',
#   10100: 'game',
#   10110: 'game',
#   10120: 'game',
#   10130: 'game',
#   10140: 'game',
#   10150: 'game',
#   10170: 'advertising',
#   10180: 'game',
#   10195: 'dlc',
#   10196: 'dlc',
#   10220: 'game',
#   10230: 'game',
#   10240: 'game',
#   10250: 'game',
#   10260: 'game',
#   10270: 'game',
#   10420: 'advertising',
#   10440: 'advertising',
#   10460: 'game',
#   10470: 'advertising',
#   10490: 'advertising',
#   10500: 'game',
#   10510: 'advertising',
#   10520: 'game',
#   10560: 'advertising',
#   10600: 'dlc',
#   10604: 'dlc',
#   10606: 'dlc',
#   10607: 'dlc',
#   10608: 'dlc',
#   10620: 'demo',
#   10680: 'game',
#   10690: 'advertising',
#   10695: 'dlc',
#   10697: 'dlc',
#   11000: 'demo',
#   11020: 'game',
#   ...},
#  'windows': {10: 1,
#   20: 1,
#   30: 1,
#   40: 1,
#   50: 1,
#   60: 1,
#   70: 1,
#   80: 1,
#   92: 1,
#   130: 1,
#   150: 1,
#   219: 1,
#   220: 1,
#   240: 1,
#   280: 1,
#   300: 1,
#   320: 1,
#   340: 1,
#   360: 1,
#   380: 1,
#   400: 1,
#   410: 1,
#   420: 1,
#   440: 1,
#   500: 1,
#   550: 1,
#   570: 1,
#   620: 1,
#   630: 1,
#   660: 1,
#   730: 1,
#   900: 1,
#   901: 1,
#   902: 1,
#   904: 1,
#   905: 1,
#   906: 1,
#   907: 1,
#   908: 1,
#   909: 1,
#   912: 1,
#   913: 1,
#   914: 1,
#   915: 1,
#   916: 1,
#   917: 1,
#   918: 1,
#   919: 1,
#   920: 1,
#   921: 1,
#   922: 1,
#   923: 1,
#   924: 1,
#   925: 1,
#   926: 1,
#   927: 1,
#   929: 1,
#   930: 1,
#   931: 1,
#   932: 1,
#   933: 1,
#   934: 1,
#   936: 1,
#   937: 1,
#   940: 1,
#   941: 1,
#   942: 1,
#   945: 1,
#   946: 1,
#   947: 1,
#   948: 1,
#   949: 1,
#   950: 1,
#   951: 1,
#   953: 1,
#   954: 1,
#   955: 1,
#   956: 1,
#   960: 1,
#   961: 1,
#   963: 1,
#   964: 1,
#   965: 1,
#   966: 1,
#   967: 1,
#   968: 1,
#   974: 1,
#   975: 1,
#   976: 1,
#   977: 1,
#   978: 1,
#   980: 1,
#   981: 1,
#   982: 1,
#   983: 1,
#   984: 1,
#   985: 1,
#   986: 1,
#   987: 1,
#   988: 1,
#   991: 1,
#   992: 1,
#   994: 1,
#   995: 1,
#   997: 1,
#   998: 1,
#   999: 1,
#   1002: 1,
#   1003: 1,
#   1200: 1,
#   1230: 1,
#   1250: 1,
#   1840: 1,
#   1900: 1,
#   1920: 1,
#   1930: 1,
#   2100: 1,
#   2120: 1,
#   2200: 1,
#   2210: 1,
#   2270: 1,
#   2280: 1,
#   2290: 1,
#   2300: 1,
#   2310: 1,
#   2320: 1,
#   2330: 1,
#   2340: 1,
#   2350: 1,
#   2360: 1,
#   2370: 1,
#   2390: 1,
#   2400: 1,
#   2420: 1,
#   2450: 1,
#   2500: 1,
#   2510: 1,
#   2520: 1,
#   2540: 1,
#   2570: 1,
#   2590: 1,
#   2600: 1,
#   2610: 1,
#   2620: 1,
#   2630: 1,
#   2640: 1,
#   2680: 1,
#   2690: 1,
#   2700: 1,
#   2710: 1,
#   2720: 1,
#   2730: 1,
#   2760: 1,
#   2780: 1,
#   2790: 1,
#   2800: 1,
#   2810: 1,
#   2820: 1,
#   2840: 1,
#   2850: 1,
#   2870: 1,
#   2900: 1,
#   2910: 1,
#   2920: 1,
#   2950: 1,
#   2990: 1,
#   3010: 1,
#   3020: 1,
#   3050: 1,
#   3130: 1,
#   3170: 1,
#   3190: 1,
#   3210: 1,
#   3230: 1,
#   3260: 1,
#   3270: 1,
#   3280: 1,
#   3300: 1,
#   3302: 1,
#   3310: 1,
#   3312: 1,
#   3320: 1,
#   3322: 1,
#   3330: 1,
#   3332: 1,
#   3340: 1,
#   3342: 1,
#   3350: 1,
#   3352: 1,
#   3360: 1,
#   3362: 1,
#   3380: 1,
#   3382: 1,
#   3390: 1,
#   3392: 1,
#   3400: 1,
#   3402: 1,
#   3410: 1,
#   3412: 1,
#   3420: 1,
#   3422: 1,
#   3430: 1,
#   3432: 1,
#   3440: 1,
#   3442: 1,
#   3450: 1,
#   3452: 1,
#   3460: 1,
#   3462: 1,
#   3480: 1,
#   3482: 1,
#   3483: 1,
#   3490: 1,
#   3492: 1,
#   3500: 1,
#   3502: 1,
#   3510: 1,
#   3512: 1,
#   3520: 1,
#   3522: 1,
#   3530: 1,
#   3532: 1,
#   3540: 1,
#   3560: 1,
#   3562: 1,
#   3570: 1,
#   3572: 1,
#   3580: 1,
#   3582: 1,
#   3590: 1,
#   3592: 1,
#   3600: 1,
#   3602: 1,
#   3610: 1,
#   3612: 1,
#   3620: 1,
#   3622: 1,
#   3700: 1,
#   3710: 1,
#   3720: 1,
#   3730: 1,
#   3800: 1,
#   3810: 1,
#   3820: 1,
#   3830: 1,
#   3838: 1,
#   3839: 1,
#   3850: 1,
#   3900: 1,
#   3910: 1,
#   3920: 1,
#   3960: 1,
#   3970: 1,
#   3980: 1,
#   3990: 1,
#   4000: 1,
#   4470: 1,
#   4500: 1,
#   4520: 1,
#   4530: 1,
#   4560: 1,
#   4570: 1,
#   4580: 1,
#   4600: 1,
#   4700: 1,
#   4710: 1,
#   4720: 1,
#   4760: 1,
#   4770: 1,
#   4780: 1,
#   4790: 1,
#   4800: 1,
#   4810: 1,
#   4820: 1,
#   4850: 1,
#   4856: 1,
#   4870: 1,
#   4880: 1,
#   4890: 1,
#   4900: 1,
#   4920: 1,
#   5000: 1,
#   5001: 1,
#   5003: 1,
#   5008: 1,
#   5015: 1,
#   5016: 1,
#   5020: 1,
#   5022: 1,
#   5024: 1,
#   5027: 1,
#   5028: 1,
#   5030: 1,
#   5031: 1,
#   5032: 1,
#   5033: 1,
#   5034: 1,
#   5035: 1,
#   5036: 1,
#   5038: 1,
#   5043: 1,
#   5044: 1,
#   5045: 1,
#   5046: 1,
#   5047: 1,
#   5048: 1,
#   5049: 1,
#   5050: 1,
#   5051: 1,
#   5052: 1,
#   5053: 1,
#   5054: 1,
#   5055: 1,
#   5056: 1,
#   5057: 1,
#   5058: 1,
#   5059: 1,
#   5062: 1,
#   5063: 1,
#   5064: 1,
#   5066: 1,
#   5067: 1,
#   5068: 1,
#   5069: 1,
#   5073: 1,
#   5076: 1,
#   5077: 1,
#   5078: 1,
#   5079: 1,
#   5080: 1,
#   5081: 1,
#   5082: 1,
#   5083: 1,
#   5084: 1,
#   5085: 1,
#   5086: 1,
#   5087: 1,
#   5088: 1,
#   5089: 1,
#   5090: 1,
#   5091: 1,
#   5092: 1,
#   5093: 1,
#   5094: 1,
#   5095: 1,
#   5096: 1,
#   5097: 1,
#   5098: 1,
#   5100: 1,
#   5102: 1,
#   5103: 1,
#   5104: 1,
#   5105: 1,
#   5107: 1,
#   5108: 1,
#   5109: 1,
#   5111: 1,
#   5112: 1,
#   5113: 1,
#   5114: 1,
#   5115: 1,
#   5116: 1,
#   5117: 1,
#   5118: 1,
#   5119: 1,
#   5120: 1,
#   5121: 1,
#   5122: 1,
#   5123: 1,
#   5124: 1,
#   5125: 1,
#   5126: 1,
#   5127: 1,
#   5128: 1,
#   5129: 1,
#   5130: 1,
#   5131: 1,
#   5132: 1,
#   5133: 1,
#   5134: 1,
#   5135: 1,
#   5136: 1,
#   5137: 1,
#   5138: 1,
#   5139: 1,
#   5140: 1,
#   5141: 1,
#   5142: 1,
#   5143: 1,
#   5144: 1,
#   5145: 1,
#   5146: 1,
#   5147: 1,
#   5149: 1,
#   5150: 1,
#   5152: 1,
#   5153: 1,
#   5157: 1,
#   5158: 1,
#   5159: 1,
#   5160: 1,
#   5161: 1,
#   5162: 1,
#   5163: 1,
#   5164: 1,
#   5165: 1,
#   5166: 1,
#   5207: 1,
#   5208: 1,
#   5209: 1,
#   5210: 1,
#   5211: 1,
#   5213: 1,
#   5214: 1,
#   5216: 1,
#   5217: 1,
#   5218: 1,
#   5219: 1,
#   5220: 1,
#   5223: 1,
#   5227: 1,
#   5231: 1,
#   5232: 1,
#   5234: 1,
#   5235: 1,
#   5236: 1,
#   5238: 1,
#   5239: 1,
#   5240: 1,
#   5241: 1,
#   5243: 1,
#   5244: 1,
#   5245: 1,
#   5246: 1,
#   5248: 1,
#   5249: 1,
#   5250: 1,
#   5251: 1,
#   5253: 1,
#   5254: 1,
#   5256: 1,
#   5257: 1,
#   5258: 1,
#   5259: 1,
#   5260: 1,
#   5262: 1,
#   5263: 1,
#   5265: 1,
#   5266: 1,
#   5267: 1,
#   5268: 1,
#   5272: 1,
#   5273: 1,
#   5274: 1,
#   5275: 1,
#   5280: 1,
#   5281: 1,
#   5282: 1,
#   5283: 1,
#   5285: 1,
#   5286: 1,
#   5288: 1,
#   5289: 1,
#   5290: 1,
#   5297: 1,
#   5300: 1,
#   5301: 1,
#   5303: 1,
#   5304: 1,
#   5305: 1,
#   5309: 1,
#   5310: 1,
#   5315: 1,
#   5319: 1,
#   5320: 1,
#   5321: 1,
#   5322: 1,
#   5323: 1,
#   5324: 1,
#   5325: 1,
#   5326: 1,
#   5327: 1,
#   5329: 1,
#   5330: 1,
#   5331: 1,
#   5332: 1,
#   5334: 1,
#   5337: 1,
#   5338: 1,
#   5339: 1,
#   5340: 1,
#   5341: 1,
#   5342: 1,
#   5343: 1,
#   5344: 1,
#   5346: 1,
#   5347: 1,
#   5348: 1,
#   5349: 1,
#   5350: 1,
#   5351: 1,
#   5353: 1,
#   5361: 1,
#   5363: 1,
#   5364: 1,
#   5365: 1,
#   5367: 1,
#   5369: 1,
#   5370: 1,
#   5371: 1,
#   5372: 1,
#   5374: 1,
#   5377: 1,
#   5379: 1,
#   5387: 1,
#   5388: 1,
#   5389: 1,
#   5390: 1,
#   5391: 1,
#   5394: 1,
#   5395: 1,
#   5396: 1,
#   5397: 1,
#   5398: 1,
#   5399: 1,
#   5400: 1,
#   5401: 1,
#   5402: 1,
#   5404: 1,
#   5405: 1,
#   5409: 1,
#   5410: 1,
#   5411: 1,
#   5414: 1,
#   5415: 1,
#   5416: 1,
#   5419: 1,
#   5420: 1,
#   5422: 1,
#   5424: 1,
#   5426: 1,
#   5427: 1,
#   5428: 1,
#   5430: 1,
#   5435: 1,
#   5445: 1,
#   5446: 1,
#   5447: 1,
#   5449: 1,
#   5451: 1,
#   5453: 1,
#   5455: 1,
#   5456: 1,
#   5459: 1,
#   5505: 1,
#   5507: 1,
#   5513: 1,
#   5514: 1,
#   5515: 1,
#   5518: 1,
#   5521: 1,
#   5522: 1,
#   5523: 1,
#   5524: 1,
#   5525: 1,
#   5526: 1,
#   5529: 1,
#   5530: 1,
#   5531: 1,
#   5532: 1,
#   5533: 1,
#   5534: 1,
#   5535: 1,
#   5536: 1,
#   5537: 1,
#   5539: 1,
#   5541: 1,
#   5544: 1,
#   5546: 1,
#   5547: 1,
#   5549: 1,
#   5550: 1,
#   5551: 1,
#   5552: 1,
#   5553: 1,
#   5561: 1,
#   5562: 1,
#   5563: 1,
#   5564: 1,
#   5565: 1,
#   5566: 1,
#   5567: 1,
#   5568: 1,
#   5569: 1,
#   5570: 1,
#   5573: 1,
#   5574: 1,
#   5576: 1,
#   5577: 1,
#   5578: 1,
#   5579: 1,
#   5580: 1,
#   5581: 1,
#   5582: 1,
#   5588: 1,
#   5589: 1,
#   5593: 1,
#   5595: 1,
#   5596: 1,
#   5597: 1,
#   5598: 1,
#   5600: 1,
#   5601: 1,
#   5604: 1,
#   5605: 1,
#   5606: 1,
#   5608: 1,
#   5610: 1,
#   5611: 1,
#   5612: 1,
#   5617: 1,
#   5619: 1,
#   5620: 1,
#   5622: 1,
#   5623: 1,
#   5626: 1,
#   5627: 1,
#   5628: 1,
#   5630: 1,
#   5631: 1,
#   5632: 1,
#   5635: 1,
#   5636: 1,
#   5637: 1,
#   5638: 1,
#   5640: 1,
#   5642: 1,
#   5643: 1,
#   5646: 1,
#   5647: 1,
#   5648: 1,
#   5649: 1,
#   5650: 1,
#   5651: 1,
#   5652: 1,
#   5653: 1,
#   5654: 1,
#   5655: 1,
#   5656: 1,
#   5658: 1,
#   5659: 1,
#   5660: 1,
#   5661: 1,
#   5663: 1,
#   5666: 1,
#   5667: 1,
#   5670: 1,
#   5674: 1,
#   5675: 1,
#   5676: 1,
#   5681: 1,
#   5682: 1,
#   5686: 1,
#   5687: 1,
#   5688: 1,
#   5689: 1,
#   5690: 1,
#   5691: 1,
#   5694: 1,
#   5695: 1,
#   5696: 1,
#   5697: 1,
#   5698: 1,
#   5700: 1,
#   5701: 1,
#   5703: 1,
#   5706: 1,
#   5712: 1,
#   5713: 1,
#   5759: 1,
#   5760: 1,
#   5761: 1,
#   5763: 1,
#   5764: 1,
#   5765: 1,
#   5766: 1,
#   5767: 1,
#   5768: 1,
#   5769: 1,
#   5770: 1,
#   5771: 1,
#   5772: 1,
#   5773: 1,
#   5775: 1,
#   5779: 1,
#   5780: 1,
#   5781: 1,
#   5782: 1,
#   5783: 1,
#   5785: 1,
#   5786: 1,
#   5787: 1,
#   5788: 1,
#   5789: 1,
#   5790: 1,
#   5791: 1,
#   5793: 1,
#   5794: 1,
#   5795: 1,
#   5796: 1,
#   5797: 1,
#   5798: 1,
#   5799: 1,
#   5801: 1,
#   5802: 1,
#   5803: 1,
#   5804: 1,
#   5805: 1,
#   5806: 1,
#   5807: 1,
#   5808: 1,
#   5809: 1,
#   5811: 1,
#   5812: 1,
#   5813: 1,
#   5814: 1,
#   5815: 1,
#   5817: 1,
#   5818: 1,
#   5819: 1,
#   5820: 1,
#   5822: 1,
#   5823: 1,
#   5824: 1,
#   5825: 1,
#   5829: 1,
#   5830: 1,
#   5831: 1,
#   5833: 1,
#   5837: 1,
#   5838: 1,
#   5839: 1,
#   5841: 1,
#   5842: 1,
#   5844: 1,
#   5852: 1,
#   5855: 1,
#   5856: 1,
#   5857: 1,
#   5858: 1,
#   5859: 1,
#   5860: 1,
#   5861: 1,
#   5864: 1,
#   5865: 1,
#   5866: 1,
#   5867: 1,
#   5869: 1,
#   5870: 1,
#   5872: 1,
#   5874: 1,
#   5877: 1,
#   5878: 1,
#   5879: 1,
#   5882: 1,
#   5883: 1,
#   5885: 1,
#   5887: 1,
#   5888: 1,
#   5889: 1,
#   5896: 1,
#   5897: 1,
#   5899: 1,
#   5901: 1,
#   5902: 1,
#   5903: 1,
#   5904: 1,
#   5905: 1,
#   5906: 1,
#   5908: 1,
#   5909: 1,
#   5910: 1,
#   5911: 1,
#   5912: 1,
#   5913: 1,
#   5914: 1,
#   5915: 1,
#   5916: 1,
#   5918: 1,
#   5922: 1,
#   5926: 1,
#   5927: 1,
#   5928: 1,
#   5929: 1,
#   5931: 1,
#   5932: 1,
#   5933: 1,
#   5939: 1,
#   5940: 1,
#   5941: 1,
#   5942: 1,
#   5945: 1,
#   5946: 1,
#   5949: 1,
#   5950: 1,
#   5951: 1,
#   5952: 1,
#   5956: 1,
#   5958: 1,
#   5959: 1,
#   5960: 1,
#   5968: 1,
#   6230: 1,
#   6250: 1,
#   6260: 1,
#   6270: 1,
#   6290: 1,
#   6300: 1,
#   6310: 1,
#   6320: 1,
#   6370: 1,
#   6400: 1,
#   6410: 1,
#   6420: 1,
#   6510: 1,
#   6550: 1,
#   6580: 1,
#   6600: 1,
#   6800: 1,
#   6810: 1,
#   6830: 1,
#   6840: 1,
#   6850: 1,
#   6860: 1,
#   6870: 1,
#   6880: 1,
#   6900: 1,
#   6910: 1,
#   6920: 1,
#   6930: 1,
#   6940: 1,
#   6950: 1,
#   6980: 1,
#   7000: 1,
#   7010: 1,
#   7020: 1,
#   7030: 1,
#   7050: 1,
#   7110: 1,
#   7200: 1,
#   7210: 1,
#   7220: 1,
#   7230: 1,
#   7260: 1,
#   7280: 1,
#   7290: 1,
#   7340: 1,
#   7400: 1,
#   7420: 1,
#   7440: 1,
#   7450: 1,
#   7470: 1,
#   7510: 1,
#   7520: 1,
#   7530: 1,
#   7600: 1,
#   7610: 1,
#   7620: 1,
#   7650: 1,
#   7660: 1,
#   7670: 1,
#   7710: 1,
#   7730: 1,
#   7740: 1,
#   7760: 1,
#   7770: 1,
#   7780: 1,
#   7800: 1,
#   7810: 1,
#   7830: 1,
#   7840: 1,
#   7860: 1,
#   7880: 1,
#   7890: 1,
#   7900: 1,
#   7910: 1,
#   7940: 1,
#   7980: 1,
#   7990: 1,
#   8000: 1,
#   8010: 1,
#   8030: 1,
#   8080: 1,
#   8090: 1,
#   8100: 1,
#   8140: 1,
#   8150: 1,
#   8170: 1,
#   8180: 1,
#   8190: 1,
#   8200: 1,
#   8210: 1,
#   8220: 1,
#   8230: 1,
#   8240: 1,
#   8250: 1,
#   8260: 1,
#   8270: 1,
#   8280: 1,
#   8290: 1,
#   8300: 1,
#   8310: 1,
#   8320: 1,
#   8330: 1,
#   8340: 1,
#   8350: 1,
#   8360: 1,
#   8370: 1,
#   8380: 1,
#   8400: 1,
#   8500: 1,
#   8600: 1,
#   8780: 1,
#   8650: 1,
#   8660: 1,
#   8690: 1,
#   8700: 1,
#   8720: 1,
#   8750: 1,
#   8760: 1,
#   8790: 1,
#   8800: 1,
#   8820: 1,
#   8830: 1,
#   8850: 1,
#   8870: 1,
#   8880: 1,
#   8890: 1,
#   8900: 1,
#   8910: 1,
#   8930: 1,
#   8970: 1,
#   8980: 1,
#   8990: 1,
#   9000: 1,
#   9010: 1,
#   9030: 1,
#   9040: 1,
#   9050: 1,
#   9060: 1,
#   9070: 1,
#   9080: 1,
#   9090: 1,
#   9940: 1,
#   9950: 1,
#   9960: 1,
#   9970: 1,
#   9980: 1,
#   9992: 1,
#   9998: 1,
#   10040: 1,
#   10080: 1,
#   10090: 1,
#   10100: 1,
#   10110: 1,
#   10120: 1,
#   10130: 1,
#   10140: 1,
#   10150: 1,
#   10170: 1,
#   10180: 1,
#   10195: 1,
#   10196: 1,
#   10220: 1,
#   10230: 1,
#   10240: 1,
#   10250: 1,
#   10260: 1,
#   10270: 1,
#   10420: 1,
#   10440: 1,
#   10460: 1,
#   10470: 1,
#   10490: 1,
#   10500: 1,
#   10510: 1,
#   10520: 1,
#   10560: 1,
#   10600: 1,
#   10604: 1,
#   10606: 1,
#   10607: 1,
#   10608: 1,
#   10620: 1,
#   10680: 1,
#   10690: 1,
#   10695: 1,
#   10697: 1,
#   11000: 1,
#   11020: 1,
#   ...}}

# %% [markdown]
# #### 3. Transfer scraped app information into dataframe

# %%
df_steam_app = pd.DataFrame(dic_steam_app)
# Transfer price to normal price
df_steam_app.initial_price = df_steam_app.initial_price.map(lambda x: x/100.0)
df_steam_app.index.name = 'steam_appid'
df_steam_app['windows'] = df_steam_app.windows.fillna(0)
df_steam_app['mac'] = df_steam_app.mac.fillna(0)
df_steam_app['linux'] = df_steam_app.linux.fillna(0)
df_steam_app = df_steam_app[['name', 'type', 'initial_price', 'release_date', 'score', 'recommendation', 'windows', 'mac', 'linux', 'header_image']]
df_steam_app.reset_index(inplace=True)
df_steam_app.to_csv('data/path_steam_app_info',encoding='utf8',index=False)

# %%
df_steam_app.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53933 entries, 0 to 53932
# Data columns (total 11 columns):
# steam_appid       53933 non-null int64
# name              53933 non-null object
# type              53933 non-null object
# initial_price     47033 non-null float64
# release_date      53413 non-null datetime64[ns]
# score             3313 non-null float64
# recommendation    8403 non-null float64
# windows           53933 non-null float64
# mac               53933 non-null float64
# linux             53933 non-null float64
# header_image      53933 non-null object
# dtypes: datetime64[ns](1), float64(6), int64(1), object(3)
# memory usage: 4.5+ MB

# %%
df_steam_app.head()
# Out:
#    steam_appid                       name  type  initial_price release_date  \
# 0           10             Counter-Strike  game           9.99   2000-11-01
# 1           20      Team Fortress Classic  game           4.99   1999-04-01
# 2           30              Day of Defeat  game           4.99   2003-05-01
# 3           40         Deathmatch Classic  game           4.99   2001-06-01
# 4           50  Half-Life: Opposing Force  game           4.99   1999-11-01
#
#    score  recommendation  windows  mac  linux  \
# 0   88.0        117473.0      1.0  1.0    1.0
# 1    NaN          3653.0      1.0  1.0    1.0
# 2   79.0          3576.0      1.0  1.0    1.0
# 3    NaN          1439.0      1.0  1.0    1.0
# 4    NaN          4987.0      1.0  1.0    1.0
#
#                                         header_image
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...

# %% [markdown]
# ### Connect to SQL

# %% [markdown]
# ####  Connect with sqlalchemy and upload dataframe

# %%
# mysql+pymysql://<username>:<password>@<host>/<dbname>[?<options>]
engine = sqlalchemy.create_engine('mysql+pymysql://<kellyshaomai@gmail.com>:<Mysql1992>@localhost:3306/gamerec?unix_socket=/tmp/mysql.sock&charset=utf8mb4')

# %%
df_steam_app.to_sql('tbl_app_info',engine,if_exists='replace')

# %%
results = engine.execute("select * from tbl_app_info limit 5")
for row in results:
    print(row)
# Out:
# (0, 10, 'Counter-Strike', 'game', 9.99, datetime.datetime(2000, 11, 1, 0, 0), 88.0, 116029.0, 1.0, 1.0, 1.0, 'https://steamcdn-a.akamaihd.net/steam/apps/10/header.jpg?t=1528733245')
# (1, 20, 'Team Fortress Classic', 'game', 4.99, datetime.datetime(1999, 4, 1, 0, 0), None, 3625.0, 1.0, 1.0, 1.0, 'https://steamcdn-a.akamaihd.net/steam/apps/20/header.jpg?t=1528732825')
# (2, 30, 'Day of Defeat', 'game', 4.99, datetime.datetime(2003, 5, 1, 0, 0), 79.0, 3530.0, 1.0, 1.0, 1.0, 'https://steamcdn-a.akamaihd.net/steam/apps/30/header.jpg?t=1512413490')
# (3, 40, 'Deathmatch Classic', 'game', 4.99, datetime.datetime(2001, 6, 1, 0, 0), None, 1412.0, 1.0, 1.0, 1.0, 'https://steamcdn-a.akamaihd.net/steam/apps/40/header.jpg?t=1528733362')
# (4, 50, 'Half-Life: Opposing Force', 'game', 4.99, datetime.datetime(1999, 11, 1, 0, 0), None, 4876.0, 1.0, 1.0, 1.0, 'https://steamcdn-a.akamaihd.net/steam/apps/50/header.jpg?t=1530046417')

# %% [markdown]
# #### 4. Prepare the usage data
# Find Most Played Games Per User from steamSPY API.

# %%
# Set path
path_app_detail = 'data/path_app_detail.txt' # Scraped info using appID
path_app_stats = 'data/app_stat.json' # Scraped info using appID
path_user_inventory = 'data/user_inventory.txt' # Scraped info using userID

# %%
with open(path_app_stats,'rb') as f:
#     read from json file
    dic_steamspy = json.load(f)

# %%
dic_steamspy
# Out:
# {'570': {'appid': 570,
#   'average_2weeks': 1161,
#   'average_forever': 11670,
#   'developer': 'Valve',
#   'median_2weeks': 614,
#   'median_forever': 258,
#   'name': 'Dota 2',
#   'negative': 104879,
#   'owners': 120750179,
#   'owners_variance': 302837,
#   'players_2weeks': 9008067,
#   'players_2weeks_variance': 94228,
#   'players_forever': 120750179,
#   'players_forever_variance': 302837,
#   'positive': 756170,
#   'price': '0',
#   'publisher': 'Valve',
#   'score_rank': 64,
#   'userscore': 87},
#  '440': {'appid': 440,
#   'average_2weeks': 689,
#   'average_forever': 4509,
#   'developer': 'Valve',
#   'median_2weeks': 403,
#   'median_forever': 218,
#   'name': 'Team Fortress 2',
#   'negative': 30274,
#   'owners': 44290079,
#   'owners_variance': 201228,
#   'players_2weeks': 1689127,
#   'players_2weeks_variance': 41109,
#   'players_forever': 44290079,
#   'players_forever_variance': 201228,
#   'positive': 464877,
#   'price': '0',
#   'publisher': 'Valve',
#   'score_rank': 86,
#   'userscore': 93},
#  '730': {'appid': 730,
#   'average_2weeks': 770,
#   'average_forever': 17418,
#   'developer': 'Valve',
#   'median_2weeks': 294,
#   'median_forever': 4063,
#   'name': 'Counter-Strike: Global Offensive',
#   'negative': 243228,
#   'owners': 39311626,
#   'owners_variance': 190624,
#   'players_2weeks': 10164670,
#   'players_2weeks_variance': 99976,
#   'players_forever': 37603087,
#   'players_forever_variance': 186784,
#   'positive': 2163708,
#   'price': '1499',
#   'publisher': 'Valve',
#   'score_rank': 70,
#   'userscore': 89},
#  '304930': {'appid': 304930,
#   'average_2weeks': 451,
#   'average_forever': 1315,
#   'developer': 'Smartly Dressed Games',
#   'median_2weeks': 73,
#   'median_forever': 155,
#   'name': 'Unturned',
#   'negative': 27010,
#   'owners': 35011290,
#   'owners_variance': 180740,
#   'players_2weeks': 753405,
#   'players_2weeks_variance': 27481,
#   'players_forever': 28014751,
#   'players_forever_variance': 162898,
#   'positive': 273719,
#   'price': '0',
#   'publisher': 'Smartly Dressed Games',
#   'score_rank': 78,
#   'userscore': 91},
#  '578080': {'appid': 578080,
#   'average_2weeks': 1635,
#   'average_forever': 11069,
#   'developer': 'PUBG Corporation',
#   'median_2weeks': 1159,
#   'median_forever': 7214,
#   'name': "PLAYERUNKNOWN'S BATTLEGROUNDS",
#   'negative': 248990,
#   'owners': 27699958,
#   'owners_variance': 162035,
#   'players_2weeks': 20074619,
#   'players_2weeks_variance': 139059,
#   'players_forever': 27528395,
#   'players_forever_variance': 161562,
#   'positive': 340154,
#   'price': '2999',
#   'publisher': 'PUBG Corporation',
#   'score_rank': 13,
#   'userscore': 56},
#  '230410': {'appid': 230410,
#   'average_2weeks': 950,
#   'average_forever': 4424,
#   'developer': 'Digital Extremes',
#   'median_2weeks': 180,
#   'median_forever': 255,
#   'name': 'Warframe',
#   'negative': 14091,
#   'owners': 20892819,
#   'owners_variance': 141743,
#   'players_2weeks': 960119,
#   'players_2weeks_variance': 31016,
#   'players_forever': 13475244,
#   'players_forever_variance': 114719,
#   'positive': 158738,
#   'price': '0',
#   'publisher': 'Digital Extremes',
#   'score_rank': 78,
#   'userscore': 91},
#  '550': {'appid': 550,
#   'average_2weeks': 255,
#   'average_forever': 2191,
#   'developer': 'Valve',
#   'median_2weeks': 81,
#   'median_forever': 510,
#   'name': 'Left 4 Dead 2',
#   'negative': 6628,
#   'owners': 19519534,
#   'owners_variance': 137203,
#   'players_2weeks': 1088135,
#   'players_2weeks_variance': 33015,
#   'players_forever': 16946887,
#   'players_forever_variance': 128187,
#   'positive': 210693,
#   'price': '1999',
#   'publisher': 'Valve',
#   'score_rank': 95,
#   'userscore': 96},
#  '227940': {'appid': 227940,
#   'average_2weeks': 331,
#   'average_forever': 806,
#   'developer': 'RETO MOTO',
#   'median_2weeks': 47,
#   'median_forever': 50,
#   'name': 'Heroes & Generals',
#   'negative': 28330,
#   'owners': 16630258,
#   'owners_variance': 127025,
#   'players_2weeks': 311383,
#   'players_2weeks_variance': 17675,
#   'players_forever': 11850387,
#   'players_forever_variance': 107761,
#   'positive': 56823,
#   'price': '0',
#   'publisher': 'RETO MOTO',
#   'score_rank': 23,
#   'userscore': 66},
#  '218620': {'appid': 218620,
#   'average_2weeks': 831,
#   'average_forever': 3332,
#   'developer': 'OVERKILL - a Starbreeze Studio.',
#   'median_2weeks': 421,
#   'median_forever': 599,
#   'name': 'PAYDAY 2',
#   'negative': 56071,
#   'owners': 16136557,
#   'owners_variance': 125190,
#   'players_2weeks': 817150,
#   'players_2weeks_variance': 28618,
#   'players_forever': 12467119,
#   'players_forever_variance': 110459,
#   'positive': 277770,
#   'price': '0',
#   'publisher': 'Starbreeze Publishing AB',
#   'score_rank': 53,
#   'userscore': 82},
#  '444090': {'appid': 444090,
#   'average_2weeks': 402,
#   'average_forever': 1359,
#   'developer': 'Hi-Rez Studios',
#   'median_2weeks': 108,
#   'median_forever': 250,
#   'name': 'Paladins',
#   'negative': 25919,
#   'owners': 16078321,
#   'owners_variance': 124972,
#   'players_2weeks': 1135878,
#   'players_2weeks_variance': 33730,
#   'players_forever': 13338571,
#   'players_forever_variance': 114152,
#   'positive': 131437,
#   'price': '0',
#   'publisher': 'Hi-Rez Studios',
#   'score_rank': 53,
#   'userscore': 83},
#  '340': {'appid': 340,
#   'average_2weeks': 313,
#   'average_forever': 104,
#   'developer': 'Valve',
#   'median_2weeks': 17,
#   'median_forever': 25,
#   'name': 'Half-Life 2: Lost Coast',
#   'negative': 877,
#   'owners': 15825699,
#   'owners_variance': 124019,
#   'players_2weeks': 21249,
#   'players_2weeks_variance': 4618,
#   'players_forever': 3006537,
#   'players_forever_variance': 54772,
#   'positive': 4798,
#   'price': '0',
#   'publisher': 'Valve',
#   'score_rank': 56,
#   'userscore': 84},
#  '240': {'appid': 240,
#   'average_2weeks': 438,
#   'average_forever': 8067,
#   'developer': 'Valve',
#   'median_2weeks': 57,
#   'median_forever': 631,
#   'name': 'Counter-Strike: Source',
#   'negative': 3004,
#   'owners': 15779792,
#   'owners_variance': 123845,
#   'players_2weeks': 296955,
#   'players_2weeks_variance': 17260,
#   'players_forever': 11567598,
#   'players_forever_variance': 106499,
#   'positive': 67177,
#   'price': '1999',
#   'publisher': 'Valve',
#   'score_rank': 92,
#   'userscore': 95},
#  '320': {'appid': 320,
#   'average_2weeks': 571,
#   'average_forever': 641,
#   'developer': 'Valve',
#   'median_2weeks': 24,
#   'median_forever': 37,
#   'name': 'Half-Life 2: Deathmatch',
#   'negative': 647,
#   'owners': 14746746,
#   'owners_variance': 119851,
#   'players_2weeks': 25446,
#   'players_2weeks_variance': 5054,
#   'players_forever': 3675997,
#   'players_forever_variance': 60523,
#   'positive': 5192,
#   'price': '499',
#   'publisher': 'Valve',
#   'score_rank': 67,
#   'userscore': 87},
#  '4000': {'appid': 4000,
#   'average_2weeks': 549,
#   'average_forever': 6215,
#   'developer': 'Facepunch Studios',
#   'median_2weeks': 131,
#   'median_forever': 1009,
#   'name': "Garry's Mod",
#   'negative': 13855,
#   'owners': 14769831,
#   'owners_variance': 119942,
#   'players_2weeks': 1275437,
#   'players_2weeks_variance': 35737,
#   'players_forever': 13792923,
#   'players_forever_variance': 116025,
#   'positive': 313486,
#   'price': '999',
#   'publisher': 'Valve',
#   'score_rank': 92,
#   'userscore': 95},
#  '10': {'appid': 10,
#   'average_2weeks': 672,
#   'average_forever': 10699,
#   'developer': 'Valve',
#   'median_2weeks': 70,
#   'median_forever': 368,
#   'name': 'Counter-Strike',
#   'negative': 2488,
#   'owners': 14062071,
#   'owners_variance': 117119,
#   'players_2weeks': 433365,
#   'players_2weeks_variance': 20849,
#   'players_forever': 9856435,
#   'players_forever_variance': 98480,
#   'positive': 105745,
#   'price': '999',
#   'publisher': 'Valve',
#   'score_rank': 97,
#   'userscore': 96},
#  '301520': {'appid': 301520,
#   'average_2weeks': 292,
#   'average_forever': 1147,
#   'developer': 'Freejam',
#   'median_2weeks': 54,
#   'median_forever': 134,
#   'name': 'Robocraft',
#   'negative': 29053,
#   'owners': 13981011,
#   'owners_variance': 116790,
#   'players_2weeks': 178120,
#   'players_2weeks_variance': 13369,
#   'players_forever': 10158898,
#   'players_forever_variance': 99948,
#   'positive': 76749,
#   'price': '0',
#   'publisher': 'Freejam',
#   'score_rank': 31,
#   'userscore': 72},
#  '236390': {'appid': 236390,
#   'average_2weeks': 541,
#   'average_forever': 2726,
#   'developer': 'Gaijin Entertainment',
#   'median_2weeks': 122,
#   'median_forever': 261,
#   'name': 'War Thunder',
#   'negative': 14898,
#   'owners': 13510133,
#   'owners_variance': 114863,
#   'players_2weeks': 463271,
#   'players_2weeks_variance': 21555,
#   'players_forever': 8195901,
#   'players_forever_variance': 89955,
#   'positive': 69385,
#   'price': '0',
#   'publisher': 'Gaijin Entertainment',
#   'score_rank': 51,
#   'userscore': 82},
#  '80': {'appid': 80,
#   'average_2weeks': 276,
#   'average_forever': 1923,
#   'developer': 'Valve',
#   'median_2weeks': 34,
#   'median_forever': 75,
#   'name': 'Counter-Strike: Condition Zero',
#   'negative': 1084,
#   'owners': 11559990,
#   'owners_variance': 106464,
#   'players_2weeks': 76075,
#   'players_2weeks_variance': 8738,
#   'players_forever': 4440682,
#   'players_forever_variance': 66469,
#   'positive': 9707,
#   'price': '999',
#   'publisher': 'Valve',
#   'score_rank': 70,
#   'userscore': 88},
#  '100': {'appid': 100,
#   'average_2weeks': 232,
#   'average_forever': 262,
#   'developer': 'Valve',
#   'median_2weeks': 31,
#   'median_forever': 32,
#   'name': 'Counter-Strike: Condition Zero',
#   'negative': 1084,
#   'owners': 11559990,
#   'owners_variance': 106464,
#   'players_2weeks': 24134,
#   'players_2weeks_variance': 4922,
#   'players_forever': 2060583,
#   'players_forever_variance': 45387,
#   'positive': 9702,
#   'price': '999',
#   'publisher': 'Valve',
#   'score_rank': 70,
#   'userscore': 88},
#  '400': {'appid': 400,
#   'average_2weeks': 140,
#   'average_forever': 328,
#   'developer': 'Valve',
#   'median_2weeks': 41,
#   'median_forever': 174,
#   'name': 'Portal',
#   'negative': 883,
#   'owners': 11543201,
#   'owners_variance': 106389,
#   'players_2weeks': 139558,
#   'players_2weeks_variance': 11834,
#   'players_forever': 7819199,
#   'players_forever_variance': 87898,
#   'positive': 42776,
#   'price': '999',
#   'publisher': 'Valve',
#   'score_rank': 97,
#   'userscore': 97},
#  '72850': {'appid': 72850,
#   'average_2weeks': 528,
#   'average_forever': 7521,
#   'developer': 'Bethesda Game Studios',
#   'median_2weeks': 127,
#   'median_forever': 3029,
#   'name': 'The Elder Scrolls V: Skyrim',
#   'negative': 14741,
#   'owners': 11617440,
#   'owners_variance': 106722,
#   'players_2weeks': 530426,
#   'players_2weeks_variance': 23063,
#   'players_forever': 11131085,
#   'players_forever_variance': 104517,
#   'positive': 226923,
#   'price': '1999',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': 86,
#   'userscore': 93},
#  '620': {'appid': 620,
#   'average_2weeks': 205,
#   'average_forever': 926,
#   'developer': 'Valve',
#   'median_2weeks': 80,
#   'median_forever': 528,
#   'name': 'Portal 2',
#   'negative': 1489,
#   'owners': 11531659,
#   'owners_variance': 106337,
#   'players_2weeks': 422347,
#   'players_2weeks_variance': 20582,
#   'players_forever': 9194845,
#   'players_forever_variance': 95182,
#   'positive': 115093,
#   'price': '1999',
#   'publisher': 'Valve',
#   'score_rank': 99,
#   'userscore': 98},
#  '220': {'appid': 220,
#   'average_2weeks': 227,
#   'average_forever': 747,
#   'developer': 'Valve',
#   'median_2weeks': 69,
#   'median_forever': 292,
#   'name': 'Half-Life 2',
#   'negative': 1967,
#   'owners': 11022219,
#   'owners_variance': 104016,
#   'players_2weeks': 153986,
#   'players_2weeks_variance': 12431,
#   'players_forever': 6277499,
#   'players_forever_variance': 78881,
#   'positive': 56545,
#   'price': '999',
#   'publisher': 'Valve',
#   'score_rank': 95,
#   'userscore': 96},
#  '8930': {'appid': 8930,
#   'average_2weeks': 751,
#   'average_forever': 10580,
#   'developer': 'Firaxis Games, Aspyr (Mac, Linux)',
#   'median_2weeks': 304,
#   'median_forever': 2539,
#   'name': "Sid Meier's Civilization V",
#   'negative': 4329,
#   'owners': 10607741,
#   'owners_variance': 102085,
#   'players_2weeks': 699628,
#   'players_2weeks_variance': 26483,
#   'players_forever': 10023275,
#   'players_forever_variance': 99293,
#   'positive': 117232,
#   'price': '2999',
#   'publisher': '2K Games, Aspyr (Mac, Linux)',
#   'score_rank': 95,
#   'userscore': 96},
#  '271590': {'appid': 271590,
#   'average_2weeks': 690,
#   'average_forever': 7533,
#   'developer': 'Rockstar North',
#   'median_2weeks': 241,
#   'median_forever': 3861,
#   'name': 'Grand Theft Auto V',
#   'negative': 116311,
#   'owners': 9787180,
#   'owners_variance': 98140,
#   'players_2weeks': 2429416,
#   'players_2weeks_variance': 49264,
#   'players_forever': 9551872,
#   'players_forever_variance': 96977,
#   'positive': 250325,
#   'price': '5999',
#   'publisher': 'Rockstar Games',
#   'score_rank': 25,
#   'userscore': 68},
#  '105600': {'appid': 105600,
#   'average_2weeks': 612,
#   'average_forever': 5022,
#   'developer': 'Re-Logic',
#   'median_2weeks': 132,
#   'median_forever': 1446,
#   'name': 'Terraria',
#   'negative': 6187,
#   'owners': 9705859,
#   'owners_variance': 97740,
#   'players_2weeks': 732943,
#   'players_2weeks_variance': 27105,
#   'players_forever': 9247835,
#   'players_forever_variance': 95451,
#   'positive': 209459,
#   'price': '999',
#   'publisher': 'Re-Logic',
#   'score_rank': 97,
#   'userscore': 97},
#  '304050': {'appid': 304050,
#   'average_2weeks': 479,
#   'average_forever': 1321,
#   'developer': 'Trion Worlds',
#   'median_2weeks': 37,
#   'median_forever': 113,
#   'name': 'Trove',
#   'negative': 12419,
#   'owners': 9619815,
#   'owners_variance': 97314,
#   'players_2weeks': 179432,
#   'players_2weeks_variance': 13419,
#   'players_forever': 7928327,
#   'players_forever_variance': 88499,
#   'positive': 43178,
#   'price': '0',
#   'publisher': 'Trion Worlds',
#   'score_rank': 40,
#   'userscore': 77},
#  '291480': {'appid': 291480,
#   'average_2weeks': 235,
#   'average_forever': 821,
#   'developer': 'Crytek',
#   'median_2weeks': 62,
#   'median_forever': 97,
#   'name': 'Warface',
#   'negative': 11078,
#   'owners': 9012789,
#   'owners_variance': 94253,
#   'players_2weeks': 271247,
#   'players_2weeks_variance': 16497,
#   'players_forever': 5914963,
#   'players_forever_variance': 76598,
#   'positive': 26897,
#   'price': '0',
#   'publisher': 'My.com',
#   'score_rank': 28,
#   'userscore': 70},
#  '218230': {'appid': 218230,
#   'average_2weeks': 433,
#   'average_forever': 1416,
#   'developer': 'Daybreak Game Company',
#   'median_2weeks': 66,
#   'median_forever': 134,
#   'name': 'PlanetSide 2',
#   'negative': 6629,
#   'owners': 8825487,
#   'owners_variance': 93286,
#   'players_2weeks': 105456,
#   'players_2weeks_variance': 10288,
#   'players_forever': 5497075,
#   'players_forever_variance': 73874,
#   'positive': 33001,
#   'price': '0',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': 53,
#   'userscore': 83},
#  '238960': {'appid': 238960,
#   'average_2weeks': 1435,
#   'average_forever': 3964,
#   'developer': 'Grinding Gear Games',
#   'median_2weeks': 364,
#   'median_forever': 257,
#   'name': 'Path of Exile',
#   'negative': 4033,
#   'owners': 8877428,
#   'owners_variance': 93555,
#   'players_2weeks': 407132,
#   'players_2weeks_variance': 20208,
#   'players_forever': 6168109,
#   'players_forever_variance': 78200,
#   'positive': 52154,
#   'price': '0',
#   'publisher': 'Grinding Gear Games',
#   'score_rank': 82,
#   'userscore': 92},
#  '224260': {'appid': 224260,
#   'average_2weeks': 161,
#   'average_forever': 403,
#   'developer': 'No More Room in Hell Team',
#   'median_2weeks': 48,
#   'median_forever': 75,
#   'name': 'No More Room in Hell',
#   'negative': 5158,
#   'owners': 8811059,
#   'owners_variance': 93211,
#   'players_2weeks': 97586,
#   'players_2weeks_variance': 9896,
#   'players_forever': 5686213,
#   'players_forever_variance': 75120,
#   'positive': 45066,
#   'price': '0',
#   'publisher': 'Lever Games',
#   'score_rank': 70,
#   'userscore': 89},
#  '291550': {'appid': 291550,
#   'average_2weeks': 276,
#   'average_forever': 892,
#   'developer': 'Blue Mammoth Games',
#   'median_2weeks': 55,
#   'median_forever': 132,
#   'name': 'Brawlhalla',
#   'negative': 8710,
#   'owners': 8638710,
#   'owners_variance': 92311,
#   'players_2weeks': 594434,
#   'players_2weeks_variance': 24414,
#   'players_forever': 7954822,
#   'players_forever_variance': 88644,
#   'positive': 52899,
#   'price': '0',
#   'publisher': 'Blue Mammoth Games',
#   'score_rank': 59,
#   'userscore': 85},
#  '333930': {'appid': 333930,
#   'average_2weeks': 357,
#   'average_forever': 704,
#   'developer': 'Splash Damage',
#   'median_2weeks': 45,
#   'median_forever': 60,
#   'name': 'Dirty Bomb',
#   'negative': 9428,
#   'owners': 8574964,
#   'owners_variance': 91976,
#   'players_2weeks': 135099,
#   'players_2weeks_variance': 11644,
#   'players_forever': 5796653,
#   'players_forever_variance': 75837,
#   'positive': 38836,
#   'price': '0',
#   'publisher': 'Warchest Ltd.',
#   'score_rank': 46,
#   'userscore': 80},
#  '273110': {'appid': 273110,
#   'average_2weeks': 550,
#   'average_forever': 1100,
#   'developer': 'Nexon',
#   'median_2weeks': 59,
#   'median_forever': 45,
#   'name': 'Counter-Strike Nexon: Zombies',
#   'negative': 10528,
#   'owners': 8594114,
#   'owners_variance': 92077,
#   'players_2weeks': 77124,
#   'players_2weeks_variance': 8798,
#   'players_forever': 5468219,
#   'players_forever_variance': 73682,
#   'positive': 20507,
#   'price': '0',
#   'publisher': 'Nexon Europe GmbH',
#   'score_rank': 23,
#   'userscore': 66},
#  '49520': {'appid': 49520,
#   'average_2weeks': 458,
#   'average_forever': 3458,
#   'developer': 'Gearbox Software, Aspyr (Mac & Linux)',
#   'median_2weeks': 121,
#   'median_forever': 1337,
#   'name': 'Borderlands 2',
#   'negative': 3999,
#   'owners': 8292175,
#   'owners_variance': 90473,
#   'players_2weeks': 348109,
#   'players_2weeks_variance': 18687,
#   'players_forever': 7403934,
#   'players_forever_variance': 85568,
#   'positive': 120500,
#   'price': '1999',
#   'publisher': '2K Games, Aspyr (Mac & Linux)',
#   'score_rank': 95,
#   'userscore': 96},
#  '439700': {'appid': 439700,
#   'average_2weeks': 105,
#   'average_forever': 106,
#   'developer': 'Daybreak Game Company',
#   'median_2weeks': 37,
#   'median_forever': 17,
#   'name': 'H1Z1 Test Server',
#   'negative': 755,
#   'owners': 8144747,
#   'owners_variance': 89679,
#   'players_2weeks': 57187,
#   'players_2weeks_variance': 7576,
#   'players_forever': 1519926,
#   'players_forever_variance': 39002,
#   'positive': 988,
#   'price': '0',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': 13,
#   'userscore': 55},
#  '433850': {'appid': 433850,
#   'average_2weeks': 356,
#   'average_forever': 5094,
#   'developer': 'Daybreak Game Company',
#   'median_2weeks': 50,
#   'median_forever': 983,
#   'name': 'H1Z1',
#   'negative': 59801,
#   'owners': 8144747,
#   'owners_variance': 89679,
#   'players_2weeks': 749470,
#   'players_2weeks_variance': 27409,
#   'players_forever': 6962961,
#   'players_forever_variance': 83018,
#   'positive': 96720,
#   'price': '1999',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': 17,
#   'userscore': 62},
#  '30': {'appid': 30,
#   'average_2weeks': 648,
#   'average_forever': 1111,
#   'developer': 'Valve',
#   'median_2weeks': 53,
#   'median_forever': 25,
#   'name': 'Day of Defeat',
#   'negative': 321,
#   'owners': 7889765,
#   'owners_variance': 88287,
#   'players_2weeks': 12329,
#   'players_2weeks_variance': 3518,
#   'players_forever': 1746839,
#   'players_forever_variance': 41803,
#   'positive': 2987,
#   'price': '499',
#   'publisher': 'Valve',
#   'score_rank': 74,
#   'userscore': 87},
#  '407530': {'appid': 407530,
#   'average_2weeks': 124,
#   'average_forever': 208,
#   'developer': 'Studio Wildcard, Instinct Games, Efecto Studios, Virtual Basement LLC',
#   'median_2weeks': 10,
#   'median_forever': 23,
#   'name': 'ARK: Survival Of The Fittest',
#   'negative': 3001,
#   'owners': 7775128,
#   'owners_variance': 87653,
#   'players_2weeks': 31217,
#   'players_2weeks_variance': 5597,
#   'players_forever': 2056124,
#   'players_forever_variance': 45338,
#   'positive': 4361,
#   'price': '0',
#   'publisher': 'Studio Wildcard',
#   'score_rank': 15,
#   'userscore': 64},
#  '360': {'appid': 360,
#   'average_2weeks': 143,
#   'average_forever': 342,
#   'developer': 'Valve',
#   'median_2weeks': 9,
#   'median_forever': 10,
#   'name': 'Half-Life Deathmatch: Source',
#   'negative': 353,
#   'owners': 7725023,
#   'owners_variance': 87375,
#   'players_2weeks': 9968,
#   'players_2weeks_variance': 3163,
#   'players_forever': 476649,
#   'players_forever_variance': 21864,
#   'positive': 993,
#   'price': '999',
#   'publisher': 'Valve',
#   'score_rank': 33,
#   'userscore': 73},
#  '40': {'appid': 40,
#   'average_2weeks': 670,
#   'average_forever': 315,
#   'developer': 'Valve',
#   'median_2weeks': 12,
#   'median_forever': 8,
#   'name': 'Deathmatch Classic',
#   'negative': 200,
#   'owners': 7755978,
#   'owners_variance': 87547,
#   'players_2weeks': 4460,
#   'players_2weeks_variance': 2115,
#   'players_forever': 843646,
#   'players_forever_variance': 29077,
#   'positive': 1042,
#   'price': '499',
#   'publisher': 'Valve',
#   'score_rank': 53,
#   'userscore': 82},
#  '60': {'appid': 60,
#   'average_2weeks': 58,
#   'average_forever': 258,
#   'developer': 'Valve',
#   'median_2weeks': 112,
#   'median_forever': 3,
#   'name': 'Ricochet',
#   'negative': 546,
#   'owners': 7743911,
#   'owners_variance': 87480,
#   'players_2weeks': 2886,
#   'players_2weeks_variance': 1702,
#   'players_forever': 895324,
#   'players_forever_variance': 29953,
#   'positive': 2229,
#   'price': '499',
#   'publisher': 'Valve',
#   'score_rank': 46,
#   'userscore': 78},
#  '322330': {'appid': 322330,
#   'average_2weeks': 412,
#   'average_forever': 1639,
#   'developer': 'Klei Entertainment',
#   'median_2weeks': 149,
#   'median_forever': 520,
#   'name': "Don't Starve Together",
#   'negative': 2765,
#   'owners': 7238930,
#   'owners_variance': 84623,
#   'players_2weeks': 476387,
#   'players_2weeks_variance': 21858,
#   'players_forever': 5935424,
#   'players_forever_variance': 76729,
#   'positive': 80338,
#   'price': '1499',
#   'publisher': 'Klei Entertainment',
#   'score_rank': 95,
#   'userscore': 96},
#  '386360': {'appid': 386360,
#   'average_2weeks': 689,
#   'average_forever': 2279,
#   'developer': 'Hi-Rez Studios',
#   'median_2weeks': 148,
#   'median_forever': 147,
#   'name': 'SMITE',
#   'negative': 5490,
#   'owners': 7283263,
#   'owners_variance': 84878,
#   'players_2weeks': 298004,
#   'players_2weeks_variance': 17291,
#   'players_forever': 5302165,
#   'players_forever_variance': 72567,
#   'positive': 28902,
#   'price': '0',
#   'publisher': 'Hi-Rez Studios',
#   'score_rank': 56,
#   'userscore': 84},
#  '380': {'appid': 380,
#   'average_2weeks': 157,
#   'average_forever': 355,
#   'developer': 'Valve',
#   'median_2weeks': 69,
#   'median_forever': 203,
#   'name': 'Half-Life 2: Episode One',
#   'negative': 397,
#   'owners': 7250472,
#   'owners_variance': 84690,
#   'players_2weeks': 32791,
#   'players_2weeks_variance': 5737,
#   'players_forever': 2672856,
#   'players_forever_variance': 51661,
#   'positive': 6186,
#   'price': '799',
#   'publisher': 'Valve',
#   'score_rank': 86,
#   'userscore': 93},
#  '252950': {'appid': 252950,
#   'average_2weeks': 460,
#   'average_forever': 5974,
#   'developer': 'Psyonix, Inc.',
#   'median_2weeks': 181,
#   'median_forever': 1187,
#   'name': 'Rocket League',
#   'negative': 14384,
#   'owners': 6865900,
#   'owners_variance': 82446,
#   'players_2weeks': 1424963,
#   'players_2weeks_variance': 37768,
#   'players_forever': 6596752,
#   'players_forever_variance': 80836,
#   'positive': 187124,
#   'price': '1999',
#   'publisher': 'Psyonix, Inc.',
#   'score_rank': 82,
#   'userscore': 93},
#  '300': {'appid': 300,
#   'average_2weeks': 435,
#   'average_forever': 1980,
#   'developer': 'Valve',
#   'median_2weeks': 65,
#   'median_forever': 109,
#   'name': 'Day of Defeat: Source',
#   'negative': 977,
#   'owners': 6787464,
#   'owners_variance': 81980,
#   'players_2weeks': 46957,
#   'players_2weeks_variance': 6865,
#   'players_forever': 3037491,
#   'players_forever_variance': 55051,
#   'positive': 9144,
#   'price': '999',
#   'publisher': 'Valve',
#   'score_rank': 74,
#   'userscore': 88},
#  '420': {'appid': 420,
#   'average_2weeks': 225,
#   'average_forever': 514,
#   'developer': 'Valve',
#   'median_2weeks': 76,
#   'median_forever': 309,
#   'name': 'Half-Life 2: Episode Two',
#   'negative': 621,
#   'owners': 6699584,
#   'owners_variance': 81455,
#   'players_2weeks': 30955,
#   'players_2weeks_variance': 5574,
#   'players_forever': 2384820,
#   'players_forever_variance': 48812,
#   'positive': 11679,
#   'price': '799',
#   'publisher': 'Valve',
#   'score_rank': 89,
#   'userscore': 94},
#  '70': {'appid': 70,
#   'average_2weeks': 245,
#   'average_forever': 588,
#   'developer': 'Valve',
#   'median_2weeks': 35,
#   'median_forever': 97,
#   'name': 'Half-Life',
#   'negative': 838,
#   'owners': 6688829,
#   'owners_variance': 81390,
#   'players_2weeks': 76337,
#   'players_2weeks_variance': 8753,
#   'players_forever': 2688333,
#   'players_forever_variance': 51809,
#   'positive': 21494,
#   'price': '999',
#   'publisher': 'Valve',
#   'score_rank': 95,
#   'userscore': 95},
#  '252490': {'appid': 252490,
#   'average_2weeks': 1027,
#   'average_forever': 6884,
#   'developer': 'Facepunch Studios',
#   'median_2weeks': 269,
#   'median_forever': 1412,
#   'name': 'Rust',
#   'negative': 42830,
#   'owners': 6587571,
#   'owners_variance': 80780,
#   'players_2weeks': 706186,
#   'players_2weeks_variance': 26607,
#   'players_forever': 6212967,
#   'players_forever_variance': 78480,
#   'positive': 178463,
#   'price': '1999',
#   'publisher': 'Facepunch Studios',
#   'score_rank': 46,
#   'userscore': 80},
#  '489830': {'appid': 489830,
#   'average_2weeks': 659,
#   'average_forever': 2193,
#   'developer': 'Bethesda Game Studios',
#   'median_2weeks': 148,
#   'median_forever': 507,
#   'name': 'The Elder Scrolls V: Skyrim Special Edition',
#   'negative': 13519,
#   'owners': 6300846,
#   'owners_variance': 79026,
#   'players_2weeks': 372505,
#   'players_2weeks_variance': 19330,
#   'players_forever': 3264142,
#   'players_forever_variance': 57055,
#   'positive': 34682,
#   'price': '3999',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': 30,
#   'userscore': 77},
#  '273350': {'appid': 273350,
#   'average_2weeks': 424,
#   'average_forever': 559,
#   'developer': 'Turtle Rock Studios',
#   'median_2weeks': 39,
#   'median_forever': 104,
#   'name': 'Evolve Stage 2',
#   'negative': 14077,
#   'owners': 6020681,
#   'owners_variance': 77271,
#   'players_2weeks': 42759,
#   'players_2weeks_variance': 6551,
#   'players_forever': 4137693,
#   'players_forever_variance': 64181,
#   'positive': 27881,
#   'price': '0',
#   'publisher': '2K',
#   'score_rank': 23,
#   'userscore': 66},
#  '208090': {'appid': 208090,
#   'average_2weeks': 213,
#   'average_forever': 378,
#   'developer': 'Edge of Reality',
#   'median_2weeks': 24,
#   'median_forever': 107,
#   'name': 'Loadout',
#   'negative': 5609,
#   'owners': 5945655,
#   'owners_variance': 76794,
#   'players_2weeks': 18363,
#   'players_2weeks_variance': 4293,
#   'players_forever': 3538275,
#   'players_forever_variance': 59386,
#   'positive': 34999,
#   'price': '0',
#   'publisher': 'Edge of Reality',
#   'score_rank': 61,
#   'userscore': 86},
#  '50': {'appid': 50,
#   'average_2weeks': 185,
#   'average_forever': 704,
#   'developer': 'Gearbox Software',
#   'median_2weeks': 72,
#   'median_forever': 115,
#   'name': 'Half-Life: Opposing Force',
#   'negative': 224,
#   'owners': 5919422,
#   'owners_variance': 76626,
#   'players_2weeks': 12329,
#   'players_2weeks_variance': 3518,
#   'players_forever': 821348,
#   'players_forever_variance': 28691,
#   'positive': 4176,
#   'price': '499',
#   'publisher': 'Valve',
#   'score_rank': 89,
#   'userscore': 94},
#  '20': {'appid': 20,
#   'average_2weeks': 686,
#   'average_forever': 870,
#   'developer': 'Valve',
#   'median_2weeks': 22,
#   'median_forever': 16,
#   'name': 'Team Fortress Classic',
#   'negative': 533,
#   'owners': 5910241,
#   'owners_variance': 76568,
#   'players_2weeks': 10493,
#   'players_2weeks_variance': 3245,
#   'players_forever': 837087,
#   'players_forever_variance': 28964,
#   'positive': 2808,
#   'price': '499',
#   'publisher': 'Valve',
#   'score_rank': 56,
#   'userscore': 81},
#  '130': {'appid': 130,
#   'average_2weeks': 617,
#   'average_forever': 540,
#   'developer': 'Gearbox Software',
#   'median_2weeks': 82,
#   'median_forever': 82,
#   'name': 'Half-Life: Blue Shift',
#   'negative': 327,
#   'owners': 5885844,
#   'owners_variance': 76411,
#   'players_2weeks': 9706,
#   'players_2weeks_variance': 3121,
#   'players_forever': 744486,
#   'players_forever_variance': 27318,
#   'positive': 2998,
#   'price': '499',
#   'publisher': 'Valve',
#   'score_rank': 74,
#   'userscore': 89},
#  '219640': {'appid': 219640,
#   'average_2weeks': 229,
#   'average_forever': 1076,
#   'developer': 'Torn Banner Studios',
#   'median_2weeks': 56,
#   'median_forever': 246,
#   'name': 'Chivalry: Medieval Warfare',
#   'negative': 9834,
#   'owners': 5764649,
#   'owners_variance': 75630,
#   'players_2weeks': 95225,
#   'players_2weeks_variance': 9776,
#   'players_forever': 4648445,
#   'players_forever_variance': 67992,
#   'positive': 48581,
#   'price': '2499',
#   'publisher': 'Torn Banner Studios',
#   'score_rank': 53,
#   'userscore': 84},
#  '346110': {'appid': 346110,
#   'average_2weeks': 1356,
#   'average_forever': 8574,
#   'developer': 'Studio Wildcard, Instinct Games, Efecto Studios, Virtual Basement LLC',
#   'median_2weeks': 457,
#   'median_forever': 1143,
#   'name': 'ARK: Survival Evolved',
#   'negative': 58200,
#   'owners': 5813179,
#   'owners_variance': 75944,
#   'players_2weeks': 650048,
#   'players_2weeks_variance': 25529,
#   'players_forever': 5548491,
#   'players_forever_variance': 74215,
#   'positive': 119185,
#   'price': '5999',
#   'publisher': 'Studio Wildcard',
#   'score_rank': 24,
#   'userscore': 68},
#  '500': {'appid': 500,
#   'average_2weeks': 313,
#   'average_forever': 2020,
#   'developer': 'Valve',
#   'median_2weeks': 52,
#   'median_forever': 363,
#   'name': 'Left 4 Dead',
#   'negative': 752,
#   'owners': 5734219,
#   'owners_variance': 75432,
#   'players_2weeks': 66631,
#   'players_2weeks_variance': 8178,
#   'players_forever': 3518862,
#   'players_forever_variance': 59224,
#   'positive': 14450,
#   'price': '1999',
#   'publisher': 'Valve',
#   'score_rank': 92,
#   'userscore': 94},
#  '226320': {'appid': 226320,
#   'average_2weeks': 8,
#   'average_forever': 1765,
#   'developer': 'Gazillion Entertainment',
#   'median_2weeks': 9,
#   'median_forever': 64,
#   'name': 'Marvel Heroes Omega',
#   'negative': 3981,
#   'owners': 5744450,
#   'owners_variance': 75499,
#   'players_2weeks': 3935,
#   'players_2weeks_variance': 1987,
#   'players_forever': 2646885,
#   'players_forever_variance': 51410,
#   'positive': 10701,
#   'price': '0',
#   'publisher': 'Gazillion Entertainment',
#   'score_rank': 31,
#   'userscore': 72},
#  '363970': {'appid': 363970,
#   'average_2weeks': 1543,
#   'average_forever': 6161,
#   'developer': 'Playsaurus',
#   'median_2weeks': 101,
#   'median_forever': 359,
#   'name': 'Clicker Heroes',
#   'negative': 4366,
#   'owners': 5580757,
#   'owners_variance': 74428,
#   'players_2weeks': 130114,
#   'players_2weeks_variance': 11427,
#   'players_forever': 4251019,
#   'players_forever_variance': 65046,
#   'positive': 40239,
#   'price': '0',
#   'publisher': 'Playsaurus',
#   'score_rank': 74,
#   'userscore': 90},
#  '113400': {'appid': 113400,
#   'average_2weeks': 268,
#   'average_forever': 1508,
#   'developer': 'Reloaded Productions',
#   'median_2weeks': 43,
#   'median_forever': 131,
#   'name': 'APB Reloaded',
#   'negative': 10823,
#   'owners': 5525931,
#   'owners_variance': 74065,
#   'players_2weeks': 42235,
#   'players_2weeks_variance': 6511,
#   'players_forever': 3435967,
#   'players_forever_variance': 58527,
#   'positive': 18377,
#   'price': '0',
#   'publisher': 'Reloaded Games',
#   'score_rank': 18,
#   'userscore': 62},
#  '109600': {'appid': 109600,
#   'average_2weeks': 657,
#   'average_forever': 1686,
#   'developer': 'Cryptic Studios',
#   'median_2weeks': 194,
#   'median_forever': 288,
#   'name': 'Neverwinter',
#   'negative': 4559,
#   'owners': 5410507,
#   'owners_variance': 73296,
#   'players_2weeks': 86306,
#   'players_2weeks_variance': 9307,
#   'players_forever': 3473742,
#   'players_forever_variance': 58846,
#   'positive': 16795,
#   'price': '0',
#   'publisher': 'Perfect World Entertainment',
#   'score_rank': 42,
#   'userscore': 78},
#  '253710': {'appid': 253710,
#   'average_2weeks': 422,
#   'average_forever': 432,
#   'developer': 'Expansive Worlds, Avalanche Studios',
#   'median_2weeks': 56,
#   'median_forever': 38,
#   'name': 'theHunter Classic',
#   'negative': 14465,
#   'owners': 5404998,
#   'owners_variance': 73260,
#   'players_2weeks': 53253,
#   'players_2weeks_variance': 7311,
#   'players_forever': 3487908,
#   'players_forever_variance': 58965,
#   'positive': 10561,
#   'price': '0',
#   'publisher': 'Expansive Worlds, Avalanche Studios',
#   'score_rank': 5,
#   'userscore': 42},
#  '339610': {'appid': 339610,
#   'average_2weeks': 359,
#   'average_forever': 851,
#   'developer': 'Joycity',
#   'median_2weeks': 64,
#   'median_forever': 63,
#   'name': 'Freestyle 2: Street Basketball',
#   'negative': 1825,
#   'owners': 5205366,
#   'owners_variance': 71909,
#   'players_2weeks': 44071,
#   'players_2weeks_variance': 6651,
#   'players_forever': 2537495,
#   'players_forever_variance': 50342,
#   'positive': 5139,
#   'price': '0',
#   'publisher': 'Joycity',
#   'score_rank': 33,
#   'userscore': 73},
#  '319630': {'appid': 319630,
#   'average_2weeks': 253,
#   'average_forever': 533,
#   'developer': 'DONTNOD Entertainment, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'median_2weeks': 82,
#   'median_forever': 159,
#   'name': 'Life is Strange - Episode 1',
#   'negative': 3666,
#   'owners': 5276720,
#   'owners_variance': 72394,
#   'players_2weeks': 137722,
#   'players_2weeks_variance': 11756,
#   'players_forever': 3278308,
#   'players_forever_variance': 57178,
#   'positive': 102466,
#   'price': '0',
#   'publisher': 'Square Enix, Feral interactive (Mac), Feral Interactive (Linux)',
#   'score_rank': 95,
#   'userscore': 96},
#  '10180': {'appid': 10180,
#   'average_2weeks': 294,
#   'average_forever': 1411,
#   'developer': 'Infinity Ward, Aspyr (Mac)',
#   'median_2weeks': 41,
#   'median_forever': 557,
#   'name': 'Call of Duty: Modern Warfare 2',
#   'negative': 2536,
#   'owners': 5235796,
#   'owners_variance': 72116,
#   'players_2weeks': 60335,
#   'players_2weeks_variance': 7782,
#   'players_forever': 4664972,
#   'players_forever_variance': 68111,
#   'positive': 26668,
#   'price': '1999',
#   'publisher': 'Activision, Aspyr (Mac)',
#   'score_rank': 78,
#   'userscore': 89},
#  '10190': {'appid': 10190,
#   'average_2weeks': 193,
#   'average_forever': 8668,
#   'developer': 'Infinity Ward, Aspyr (Mac)',
#   'median_2weeks': 39,
#   'median_forever': 2220,
#   'name': 'Call of Duty: Modern Warfare 2',
#   'negative': 2537,
#   'owners': 5235796,
#   'owners_variance': 72116,
#   'players_2weeks': 107292,
#   'players_2weeks_variance': 10377,
#   'players_forever': 4580502,
#   'players_forever_variance': 67497,
#   'positive': 26669,
#   'price': '1999',
#   'publisher': 'Activision, Aspyr (Mac)',
#   'score_rank': 78,
#   'userscore': 89},
#  '203160': {'appid': 203160,
#   'average_2weeks': 240,
#   'average_forever': 900,
#   'developer': 'Crystal Dynamics, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'median_2weeks': 89,
#   'median_forever': 630,
#   'name': 'Tomb Raider',
#   'negative': 3118,
#   'owners': 5204055,
#   'owners_variance': 71900,
#   'players_2weeks': 125393,
#   'players_2weeks_variance': 11218,
#   'players_forever': 4238165,
#   'players_forever_variance': 64949,
#   'positive': 74378,
#   'price': '1999',
#   'publisher': 'Square Enix, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'score_rank': 92,
#   'userscore': 95},
#  '377160': {'appid': 377160,
#   'average_2weeks': 798,
#   'average_forever': 7046,
#   'developer': 'Bethesda Game Studios',
#   'median_2weeks': 247,
#   'median_forever': 3363,
#   'name': 'Fallout 4',
#   'negative': 41755,
#   'owners': 5143719,
#   'owners_variance': 71486,
#   'players_2weeks': 517310,
#   'players_2weeks_variance': 22777,
#   'players_forever': 4937268,
#   'players_forever_variance': 70051,
#   'positive': 91204,
#   'price': '2999',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': 25,
#   'userscore': 68},
#  '20920': {'appid': 20920,
#   'average_2weeks': 340,
#   'average_forever': 926,
#   'developer': 'CD PROJEKT RED',
#   'median_2weeks': 76,
#   'median_forever': 293,
#   'name': 'The Witcher 2: Assassins of Kings Enhanced Edition',
#   'negative': 3875,
#   'owners': 5149228,
#   'owners_variance': 71524,
#   'players_2weeks': 59024,
#   'players_2weeks_variance': 7697,
#   'players_forever': 3560310,
#   'players_forever_variance': 59570,
#   'positive': 30950,
#   'price': '1999',
#   'publisher': 'CD PROJEKT RED, 1C-SoftClub',
#   'score_rank': 67,
#   'userscore': 88},
#  '8870': {'appid': 8870,
#   'average_2weeks': 285,
#   'average_forever': 902,
#   'developer': 'Irrational Games, Aspyr (Mac), Virtual Programming (Linux)',
#   'median_2weeks': 93,
#   'median_forever': 632,
#   'name': 'BioShock Infinite',
#   'negative': 3252,
#   'owners': 5038526,
#   'owners_variance': 70759,
#   'players_2weeks': 65057,
#   'players_2weeks_variance': 8081,
#   'players_forever': 3790634,
#   'players_forever_variance': 61452,
#   'positive': 70612,
#   'price': '2999',
#   'publisher': '2K Games, Aspyr (Mac)',
#   'score_rank': 92,
#   'userscore': 95},
#  '22380': {'appid': 22380,
#   'average_2weeks': 379,
#   'average_forever': 3576,
#   'developer': 'Obsidian Entertainment',
#   'median_2weeks': 88,
#   'median_forever': 1239,
#   'name': 'Fallout: New Vegas',
#   'negative': 2560,
#   'owners': 5080499,
#   'owners_variance': 71050,
#   'players_2weeks': 162905,
#   'players_2weeks_variance': 12786,
#   'players_forever': 4453011,
#   'players_forever_variance': 66560,
#   'positive': 55397,
#   'price': '999',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': 92,
#   'userscore': 95},
#  '630': {'appid': 630,
#   'average_2weeks': 319,
#   'average_forever': 324,
#   'developer': 'Valve',
#   'median_2weeks': 37,
#   'median_forever': 91,
#   'name': 'Alien Swarm',
#   'negative': 855,
#   'owners': 4991569,
#   'owners_variance': 70432,
#   'players_2weeks': 20199,
#   'players_2weeks_variance': 4503,
#   'players_forever': 4991569,
#   'players_forever_variance': 70432,
#   'positive': 16732,
#   'price': '0',
#   'publisher': 'Valve',
#   'score_rank': 92,
#   'userscore': 95},
#  '227300': {'appid': 227300,
#   'average_2weeks': 454,
#   'average_forever': 4480,
#   'developer': 'SCS Software',
#   'median_2weeks': 158,
#   'median_forever': 1270,
#   'name': 'Euro Truck Simulator 2',
#   'negative': 3705,
#   'owners': 4930447,
#   'owners_variance': 70003,
#   'players_2weeks': 892438,
#   'players_2weeks_variance': 29905,
#   'players_forever': 4632181,
#   'players_forever_variance': 67874,
#   'positive': 128983,
#   'price': '499',
#   'publisher': 'SCS Software',
#   'score_rank': 97,
#   'userscore': 96},
#  '1250': {'appid': 1250,
#   'average_2weeks': 356,
#   'average_forever': 1987,
#   'developer': 'Tripwire Interactive',
#   'median_2weeks': 83,
#   'median_forever': 349,
#   'name': 'Killing Floor',
#   'negative': 2426,
#   'owners': 5024623,
#   'owners_variance': 70662,
#   'players_2weeks': 72140,
#   'players_2weeks_variance': 8509,
#   'players_forever': 3737381,
#   'players_forever_variance': 61022,
#   'positive': 51322,
#   'price': '1999',
#   'publisher': 'Tripwire Interactive',
#   'score_rank': 92,
#   'userscore': 96},
#  '555570': {'appid': 555570,
#   'average_2weeks': 428,
#   'average_forever': 817,
#   'developer': 'Fredaikis AB',
#   'median_2weeks': 52,
#   'median_forever': 50,
#   'name': 'Infestation: The New Z',
#   'negative': 12287,
#   'owners': 4961664,
#   'owners_variance': 70222,
#   'players_2weeks': 157397,
#   'players_2weeks_variance': 12568,
#   'players_forever': 3770959,
#   'players_forever_variance': 61293,
#   'positive': 11528,
#   'price': '0',
#   'publisher': 'Fredaikis AB',
#   'score_rank': 8,
#   'userscore': 48},
#  '550650': {'appid': 550650,
#   'average_2weeks': 317,
#   'average_forever': 518,
#   'developer': 'NS STUDIO',
#   'median_2weeks': 63,
#   'median_forever': 65,
#   'name': 'Black Squad',
#   'negative': 5547,
#   'owners': 4860143,
#   'owners_variance': 69508,
#   'players_2weeks': 490553,
#   'players_2weeks_variance': 22180,
#   'players_forever': 3412095,
#   'players_forever_variance': 58325,
#   'positive': 15358,
#   'price': '0',
#   'publisher': 'NEOWIZ, NEOBRICKS',
#   'score_rank': 33,
#   'userscore': 73},
#  '222880': {'appid': 222880,
#   'average_2weeks': 202,
#   'average_forever': 1167,
#   'developer': 'New World Interactive',
#   'median_2weeks': 63,
#   'median_forever': 248,
#   'name': 'Insurgency',
#   'negative': 7168,
#   'owners': 4863554,
#   'owners_variance': 69532,
#   'players_2weeks': 390606,
#   'players_2weeks_variance': 19794,
#   'players_forever': 3983445,
#   'players_forever_variance': 62983,
#   'positive': 73631,
#   'price': '149',
#   'publisher': 'New World Interactive',
#   'score_rank': 78,
#   'userscore': 91},
#  '221380': {'appid': 221380,
#   'average_2weeks': 473,
#   'average_forever': 2816,
#   'developer': 'Skybox Labs, Hidden Path Entertainment, Ensemble Studios',
#   'median_2weeks': 184,
#   'median_forever': 625,
#   'name': 'Age of Empires II HD',
#   'negative': 2665,
#   'owners': 4818433,
#   'owners_variance': 69212,
#   'players_2weeks': 424446,
#   'players_2weeks_variance': 20633,
#   'players_forever': 4401070,
#   'players_forever_variance': 66174,
#   'positive': 43876,
#   'price': '1999',
#   'publisher': 'Microsoft Studios',
#   'score_rank': 89,
#   'userscore': 94},
#  '346900': {'appid': 346900,
#   'average_2weeks': 714,
#   'average_forever': 2412,
#   'developer': 'Hyper Hippo Games',
#   'median_2weeks': 29,
#   'median_forever': 175,
#   'name': 'AdVenture Capitalist',
#   'negative': 3803,
#   'owners': 4722684,
#   'owners_variance': 68527,
#   'players_2weeks': 91028,
#   'players_2weeks_variance': 9558,
#   'players_forever': 3678620,
#   'players_forever_variance': 60544,
#   'positive': 34065,
#   'price': '0',
#   'publisher': 'Hyper Hippo Games',
#   'score_rank': 70,
#   'userscore': 89},
#  '292030': {'appid': 292030,
#   'average_2weeks': 634,
#   'average_forever': 3931,
#   'developer': 'CD PROJEKT RED',
#   'median_2weeks': 167,
#   'median_forever': 1524,
#   'name': 'The Witcher 3: Wild Hunt',
#   'negative': 3204,
#   'owners': 4597816,
#   'owners_variance': 67624,
#   'players_2weeks': 506030,
#   'players_2weeks_variance': 22527,
#   'players_forever': 4006529,
#   'players_forever_variance': 63164,
#   'positive': 141369,
#   'price': '3999',
#   'publisher': 'CD PROJEKT RED',
#   'score_rank': 97,
#   'userscore': 97},
#  '323370': {'appid': 323370,
#   'average_2weeks': 760,
#   'average_forever': 1844,
#   'developer': 'Bluehole, Inc.',
#   'median_2weeks': 115,
#   'median_forever': 249,
#   'name': 'TERA',
#   'negative': 2515,
#   'owners': 4611981,
#   'owners_variance': 67727,
#   'players_2weeks': 58761,
#   'players_2weeks_variance': 7680,
#   'players_forever': 2681250,
#   'players_forever_variance': 51741,
#   'positive': 10261,
#   'price': '0',
#   'publisher': 'En Masse Entertainment',
#   'score_rank': 46,
#   'userscore': 80},
#  '506540': {'appid': 506540,
#   'average_2weeks': 142,
#   'average_forever': 395,
#   'developer': 'Free Reign Entertainment, Free Reign Entertainment',
#   'median_2weeks': 32,
#   'median_forever': 67,
#   'name': 'Last Man Standing',
#   'negative': 6734,
#   'owners': 4650806,
#   'owners_variance': 68009,
#   'players_2weeks': 162643,
#   'players_2weeks_variance': 12776,
#   'players_forever': 3431507,
#   'players_forever_variance': 58490,
#   'positive': 11675,
#   'price': '0',
#   'publisher': 'Free Reign Entertainment',
#   'score_rank': 19,
#   'userscore': 63},
#  '219740': {'appid': 219740,
#   'average_2weeks': 361,
#   'average_forever': 1473,
#   'developer': 'Klei Entertainment',
#   'median_2weeks': 68,
#   'median_forever': 367,
#   'name': "Don't Starve",
#   'negative': 1619,
#   'owners': 4567123,
#   'owners_variance': 67400,
#   'players_2weeks': 139821,
#   'players_2weeks_variance': 11846,
#   'players_forever': 3946194,
#   'players_forever_variance': 62690,
#   'positive': 55762,
#   'price': '1499',
#   'publisher': 'Klei Entertainment',
#   'score_rank': 97,
#   'userscore': 97},
#  '280790': {'appid': 280790,
#   'average_2weeks': 293,
#   'average_forever': 536,
#   'developer': 'Playful Corporation',
#   'median_2weeks': 56,
#   'median_forever': 73,
#   'name': 'Creativerse',
#   'negative': 4080,
#   'owners': 4515970,
#   'owners_variance': 67025,
#   'players_2weeks': 82896,
#   'players_2weeks_variance': 9121,
#   'players_forever': 3855691,
#   'players_forever_variance': 61973,
#   'positive': 16655,
#   'price': '0',
#   'publisher': 'Playful Corporation',
#   'score_rank': 46,
#   'userscore': 80},
#  '43110': {'appid': 43110,
#   'average_2weeks': 391,
#   'average_forever': 476,
#   'developer': '4A Games',
#   'median_2weeks': 71,
#   'median_forever': 164,
#   'name': 'Metro 2033',
#   'negative': 1213,
#   'owners': 4504952,
#   'owners_variance': 66944,
#   'players_2weeks': 11805,
#   'players_2weeks_variance': 3442,
#   'players_forever': 2980566,
#   'players_forever_variance': 54536,
#   'positive': 15592,
#   'price': '1499',
#   'publisher': 'Deep Silver',
#   'score_rank': 82,
#   'userscore': 93},
#  '238320': {'appid': 238320,
#   'average_2weeks': 136,
#   'average_forever': 275,
#   'developer': 'Red Barrels',
#   'median_2weeks': 28,
#   'median_forever': 108,
#   'name': 'Outlast',
#   'negative': 1588,
#   'owners': 4376936,
#   'owners_variance': 65994,
#   'players_2weeks': 81584,
#   'players_2weeks_variance': 9049,
#   'players_forever': 2368031,
#   'players_forever_variance': 48641,
#   'positive': 39638,
#   'price': '1999',
#   'publisher': 'Red Barrels',
#   'score_rank': 95,
#   'userscore': 96},
#  '504370': {'appid': 504370,
#   'average_2weeks': 322,
#   'average_forever': 885,
#   'developer': 'Stunlock Studios',
#   'median_2weeks': 87,
#   'median_forever': 194,
#   'name': 'Battlerite',
#   'negative': 5430,
#   'owners': 4430451,
#   'owners_variance': 66393,
#   'players_2weeks': 563480,
#   'players_2weeks_variance': 23770,
#   'players_forever': 3342054,
#   'players_forever_variance': 57728,
#   'positive': 35685,
#   'price': '0',
#   'publisher': 'Stunlock Studios',
#   'score_rank': 61,
#   'userscore': 86},
#  '12210': {'appid': 12210,
#   'average_2weeks': 374,
#   'average_forever': 1463,
#   'developer': 'Rockstar North, Rockstar Toronto',
#   'median_2weeks': 62,
#   'median_forever': 463,
#   'name': 'Grand Theft Auto IV',
#   'negative': 16510,
#   'owners': 4400283,
#   'owners_variance': 66168,
#   'players_2weeks': 82371,
#   'players_2weeks_variance': 9092,
#   'players_forever': 3747087,
#   'players_forever_variance': 61101,
#   'positive': 30441,
#   'price': '1999',
#   'publisher': 'Rockstar Games',
#   'score_rank': 21,
#   'userscore': 63},
#  '200110': {'appid': 200110,
#   'average_2weeks': 1364,
#   'average_forever': 423,
#   'developer': 'Psyonix',
#   'median_2weeks': 2150,
#   'median_forever': 58,
#   'name': 'Nosgoth',
#   'negative': 3860,
#   'owners': 4424417,
#   'owners_variance': 66348,
#   'players_2weeks': 1574,
#   'players_2weeks_variance': 1257,
#   'players_forever': 2352292,
#   'players_forever_variance': 48479,
#   'positive': 11015,
#   'price': '0',
#   'publisher': 'Square Enix',
#   'score_rank': '',
#   'userscore': 0},
#  '8190': {'appid': 8190,
#   'average_2weeks': 206,
#   'average_forever': 1023,
#   'developer': 'Avalanche Studios',
#   'median_2weeks': 41,
#   'median_forever': 227,
#   'name': 'Just Cause 2',
#   'negative': 2594,
#   'owners': 4350179,
#   'owners_variance': 65794,
#   'players_2weeks': 46957,
#   'players_2weeks_variance': 6865,
#   'players_forever': 3451444,
#   'players_forever_variance': 58658,
#   'positive': 30191,
#   'price': '1499',
#   'publisher': 'Square Enix',
#   'score_rank': 82,
#   'userscore': 91},
#  '255710': {'appid': 255710,
#   'average_2weeks': 455,
#   'average_forever': 2529,
#   'developer': 'Colossal Order Ltd.',
#   'median_2weeks': 133,
#   'median_forever': 727,
#   'name': 'Cities: Skylines',
#   'negative': 4042,
#   'owners': 4335488,
#   'owners_variance': 65684,
#   'players_2weeks': 373554,
#   'players_2weeks_variance': 19358,
#   'players_forever': 4117232,
#   'players_forever_variance': 64023,
#   'positive': 50836,
#   'price': '2999',
#   'publisher': 'Paradox Interactive',
#   'score_rank': 82,
#   'userscore': 92},
#  '241930': {'appid': 241930,
#   'average_2weeks': 293,
#   'average_forever': 1273,
#   'developer': 'Monolith Productions, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'median_2weeks': 78,
#   'median_forever': 870,
#   'name': 'Middle-earth: Shadow of Mordor',
#   'negative': 3949,
#   'owners': 4350441,
#   'owners_variance': 65796,
#   'players_2weeks': 82109,
#   'players_2weeks_variance': 9078,
#   'players_forever': 3652125,
#   'players_forever_variance': 60327,
#   'positive': 47156,
#   'price': '1999',
#   'publisher': 'WB Games, Feral Interactive (Mac)',
#   'score_rank': 82,
#   'userscore': 91},
#  '359550': {'appid': 359550,
#   'average_2weeks': 791,
#   'average_forever': 6088,
#   'developer': 'Ubisoft Montreal',
#   'median_2weeks': 352,
#   'median_forever': 1573,
#   'name': "Tom Clancy's Rainbow Six Siege",
#   'negative': 23529,
#   'owners': 4326831,
#   'owners_variance': 65619,
#   'players_2weeks': 1721918,
#   'players_2weeks_variance': 41504,
# ...
#   'players_forever': 565054,
#   'players_forever_variance': 23803,
#   'positive': 20454,
#   'price': '5999',
#   'publisher': 'Ubisoft',
#   'score_rank': 61,
#   'userscore': 85},
#  '201570': {'appid': 201570,
#   'average_2weeks': 66,
#   'average_forever': 133,
#   'developer': 'Boss Baddie',
#   'median_2weeks': 123,
#   'median_forever': 87,
#   'name': 'Really Big Sky',
#   'negative': 471,
#   'owners': 599681,
#   'owners_variance': 24521,
#   'players_2weeks': 1570,
#   'players_2weeks_variance': 1536,
#   'players_forever': 354142,
#   'players_forever_variance': 18848,
#   'positive': 1425,
#   'price': '499',
#   'publisher': 'Ripstone',
#   'score_rank': 37,
#   'userscore': 74},
#  '94200': {'appid': 94200,
#   'average_2weeks': 104,
#   'average_forever': 123,
#   'developer': 'Final Form Games',
#   'median_2weeks': 154,
#   'median_forever': 44,
#   'name': 'Jamestown',
#   'negative': 96,
#   'owners': 614371,
#   'owners_variance': 24819,
#   'players_2weeks': 1049,
#   'players_2weeks_variance': 1026,
#   'players_forever': 361487,
#   'players_forever_variance': 19043,
#   'positive': 1857,
#   'price': '999',
#   'publisher': 'Final Form Games',
#   'score_rank': 92,
#   'userscore': 95},
#  '26500': {'appid': 26500,
#   'average_2weeks': 1,
#   'average_forever': 108,
#   'developer': 'Lazy 8 Studios',
#   'median_2weeks': 1,
#   'median_forever': 23,
#   'name': 'Cogs',
#   'negative': 77,
#   'owners': 617781,
#   'owners_variance': 24888,
#   'players_2weeks': 784,
#   'players_2weeks_variance': 1536,
#   'players_forever': 316892,
#   'players_forever_variance': 17830,
#   'positive': 623,
#   'price': '999',
#   'publisher': '',
#   'score_rank': 70,
#   'userscore': 92},
#  '26900': {'appid': 26900,
#   'average_2weeks': 10,
#   'average_forever': 71,
#   'developer': 'Kloonigames',
#   'median_2weeks': 10,
#   'median_forever': 27,
#   'name': 'Crayon Physics Deluxe',
#   'negative': 102,
#   'owners': 604140,
#   'owners_variance': 24612,
#   'players_2weeks': 785,
#   'players_2weeks_variance': 1086,
#   'players_forever': 312694,
#   'players_forever_variance': 17712,
#   'positive': 611,
#   'price': '1999',
#   'publisher': 'Kloonigames',
#   'score_rank': 59,
#   'userscore': 93},
#  '205910': {'appid': 205910,
#   'average_2weeks': 173,
#   'average_forever': 158,
#   'developer': 'Black Pants Studio',
#   'median_2weeks': 262,
#   'median_forever': 93,
#   'name': "Tiny and Big: Grandpa's Leftovers",
#   'negative': 281,
#   'owners': 611748,
#   'owners_variance': 24766,
#   'players_2weeks': 1962,
#   'players_2weeks_variance': 1717,
#   'players_forever': 312170,
#   'players_forever_variance': 17697,
#   'positive': 3307,
#   'price': '999',
#   'publisher': 'Black Pants Studio',
#   'score_rank': 82,
#   'userscore': 92},
#  '12170': {'appid': 12170,
#   'average_2weeks': 4,
#   'average_forever': 58,
#   'developer': 'Rockstar North',
#   'median_2weeks': 4,
#   'median_forever': 5,
#   'name': 'Grand Theft Auto',
#   'negative': 25,
#   'owners': 596533,
#   'owners_variance': 24457,
#   'players_2weeks': 791,
#   'players_2weeks_variance': 1550,
#   'players_forever': 199894,
#   'players_forever_variance': 14163,
#   'positive': 166,
#   'price': '0',
#   'publisher': 'Rockstar Games',
#   'score_rank': 61,
#   'userscore': 85},
#  '12180': {'appid': 12180,
#   'average_2weeks': 0,
#   'average_forever': 54,
#   'developer': 'Rockstar North',
#   'median_2weeks': 0,
#   'median_forever': 9,
#   'name': 'Grand Theft Auto 2',
#   'negative': 15,
#   'owners': 596533,
#   'owners_variance': 24457,
#   'players_2weeks': 0,
#   'players_2weeks_variance': 0,
#   'players_forever': 163692,
#   'players_forever_variance': 12817,
#   'positive': 144,
#   'price': '0',
#   'publisher': 'Rockstar Games',
#   'score_rank': 74,
#   'userscore': 86},
#  '226860': {'appid': 226860,
#   'average_2weeks': 844,
#   'average_forever': 2910,
#   'developer': 'Stardock Entertainment',
#   'median_2weeks': 376,
#   'median_forever': 444,
#   'name': 'Galactic Civilizations III',
#   'negative': 1675,
#   'owners': 606764,
#   'owners_variance': 24665,
#   'players_2weeks': 14428,
#   'players_2weeks_variance': 3805,
#   'players_forever': 406083,
#   'players_forever_variance': 20182,
#   'positive': 5413,
#   'price': '1499',
#   'publisher': 'Stardock Entertainment',
#   'score_rank': 39,
#   'userscore': 76},
#  '290140': {'appid': 290140,
#   'average_2weeks': 197,
#   'average_forever': 889,
#   'developer': 'Mr. Blue',
#   'median_2weeks': 290,
#   'median_forever': 93,
#   'name': 'Echo of Soul',
#   'negative': 629,
#   'owners': 613584,
#   'owners_variance': 24803,
#   'players_2weeks': 2356,
#   'players_2weeks_variance': 2664,
#   'players_forever': 374341,
#   'players_forever_variance': 19378,
#   'positive': 961,
#   'price': '0',
#   'publisher': 'Aeria Games',
#   'score_rank': 16,
#   'userscore': 60},
#  '261180': {'appid': 261180,
#   'average_2weeks': 91,
#   'average_forever': 329,
#   'developer': 'Team Reptile',
#   'median_2weeks': 35,
#   'median_forever': 166,
#   'name': 'Lethal League',
#   'negative': 233,
#   'owners': 568989,
#   'owners_variance': 23886,
#   'players_2weeks': 16002,
#   'players_2weeks_variance': 4008,
#   'players_forever': 430742,
#   'players_forever_variance': 20785,
#   'positive': 4233,
#   'price': '1399',
#   'publisher': 'Team Reptile',
#   'score_rank': 89,
#   'userscore': 95},
#  '220700': {'appid': 220700,
#   'average_2weeks': 365,
#   'average_forever': 2697,
#   'developer': 'KADOKAWA',
#   'median_2weeks': 146,
#   'median_forever': 201,
#   'name': 'RPG Maker VX Ace',
#   'negative': 213,
#   'owners': 591024,
#   'owners_variance': 24344,
#   'players_2weeks': 12067,
#   'players_2weeks_variance': 3480,
#   'players_forever': 456450,
#   'players_forever_variance': 21396,
#   'positive': 3259,
#   'price': '6999',
#   'publisher': 'Degica',
#   'score_rank': 86,
#   'userscore': 93},
#  '18500': {'appid': 18500,
#   'average_2weeks': 106,
#   'average_forever': 1474,
#   'developer': 'Hidden Path Entertainment',
#   'median_2weeks': 129,
#   'median_forever': 317,
#   'name': 'Defense Grid: The Awakening',
#   'negative': 94,
#   'owners': 586302,
#   'owners_variance': 24246,
#   'players_2weeks': 2361,
#   'players_2weeks_variance': 1539,
#   'players_forever': 454614,
#   'players_forever_variance': 21353,
#   'positive': 3072,
#   'price': '999',
#   'publisher': 'Hidden Path Entertainment',
#   'score_rank': 97,
#   'userscore': 97},
#  '209830': {'appid': 209830,
#   'average_2weeks': 10,
#   'average_forever': 62,
#   'developer': 'Jasper Byrne',
#   'median_2weeks': 11,
#   'median_forever': 22,
#   'name': "Lone Survivor: The Director's Cut",
#   'negative': 138,
#   'owners': 582105,
#   'owners_variance': 24159,
#   'players_2weeks': 1177,
#   'players_2weeks_variance': 1330,
#   'players_forever': 277543,
#   'players_forever_variance': 16687,
#   'positive': 985,
#   'price': '1499',
#   'publisher': 'Superflat Games',
#   'score_rank': 64,
#   'userscore': 89},
#  '46500': {'appid': 46500,
#   'average_2weeks': 184,
#   'average_forever': 262,
#   'developer': 'Microids',
#   'median_2weeks': 114,
#   'median_forever': 126,
#   'name': 'Syberia',
#   'negative': 225,
#   'owners': 569513,
#   'owners_variance': 23897,
#   'players_2weeks': 5247,
#   'players_2weeks_variance': 2295,
#   'players_forever': 286986,
#   'players_forever_variance': 16968,
#   'positive': 1865,
#   'price': '1299',
#   'publisher': 'Microids',
#   'score_rank': 70,
#   'userscore': 89},
#  '44630': {'appid': 44630,
#   'average_2weeks': 1,
#   'average_forever': 2,
#   'developer': '',
#   'median_2weeks': 1,
#   'median_forever': 1,
#   'name': 'RACE 07 - Formula RaceRoom Add-On',
#   'negative': 0,
#   'owners': 570563,
#   'owners_variance': 23919,
#   'players_2weeks': 784,
#   'players_2weeks_variance': 1536,
#   'players_forever': 75026,
#   'players_forever_variance': 8678,
#   'positive': 0,
#   'price': '0',
#   'publisher': '',
#   'score_rank': '',
#   'userscore': 0},
#  '333600': {'appid': 333600,
#   'average_2weeks': 116,
#   'average_forever': 341,
#   'developer': 'NEKO WORKs',
#   'median_2weeks': 21,
#   'median_forever': 143,
#   'name': 'NEKOPARA Vol. 1',
#   'negative': 626,
#   'owners': 589188,
#   'owners_variance': 24306,
#   'players_2weeks': 20199,
#   'players_2weeks_variance': 4503,
#   'players_forever': 423397,
#   'players_forever_variance': 20608,
#   'positive': 14014,
#   'price': '999',
#   'publisher': 'Sekai Project',
#   'score_rank': 92,
#   'userscore': 96},
#  '304390': {'appid': 304390,
#   'average_2weeks': 614,
#   'average_forever': 3452,
#   'developer': 'Ubisoft Montreal, Ubisoft Quebec, Ubisoft Toronto, Blue Byte',
#   'median_2weeks': 194,
#   'median_forever': 1357,
#   'name': 'FOR HONOR',
#   'negative': 15124,
#   'owners': 591024,
#   'owners_variance': 24344,
#   'players_2weeks': 78174,
#   'players_2weeks_variance': 8858,
#   'players_forever': 578170,
#   'players_forever_variance': 24078,
#   'positive': 13254,
#   'price': '5999',
#   'publisher': 'Ubisoft',
#   'score_rank': 7,
#   'userscore': 47},
#  '224980': {'appid': 224980,
#   'average_2weeks': 355,
#   'average_forever': 593,
#   'developer': 'Core Design',
#   'median_2weeks': 359,
#   'median_forever': 20,
#   'name': 'Tomb Raider IV: The Last Revelation',
#   'negative': 41,
#   'owners': 566628,
#   'owners_variance': 23836,
#   'players_2weeks': 1177,
#   'players_2weeks_variance': 1330,
#   'players_forever': 82371,
#   'players_forever_variance': 9092,
#   'positive': 334,
#   'price': '699',
#   'publisher': 'Square Enix',
#   'score_rank': 70,
#   'userscore': 88},
#  '245470': {'appid': 245470,
#   'average_2weeks': 186,
#   'average_forever': 506,
#   'developer': 'Positech Games',
#   'median_2weeks': 123,
#   'median_forever': 220,
#   'name': 'Democracy 3',
#   'negative': 1371,
#   'owners': 613584,
#   'owners_variance': 24803,
#   'players_2weeks': 10493,
#   'players_2weeks_variance': 3245,
#   'players_forever': 542756,
#   'players_forever_variance': 23329,
#   'positive': 4169,
#   'price': '2499',
#   'publisher': 'Positech Games',
#   'score_rank': 37,
#   'userscore': 74},
#  '242640': {'appid': 242640,
#   'average_2weeks': 144,
#   'average_forever': 507,
#   'developer': 'Cyanide Studio',
#   'median_2weeks': 108,
#   'median_forever': 164,
#   'name': 'Styx: Master of Shadows',
#   'negative': 835,
#   'owners': 585253,
#   'owners_variance': 24225,
#   'players_2weeks': 7083,
#   'players_2weeks_variance': 2666,
#   'players_forever': 397164,
#   'players_forever_variance': 19959,
#   'positive': 4013,
#   'price': '2999',
#   'publisher': 'Focus Home Interactive',
#   'score_rank': 51,
#   'userscore': 82},
#  '485310': {'appid': 485310,
#   'average_2weeks': 128,
#   'average_forever': 245,
#   'developer': 'Indie Game Group',
#   'median_2weeks': 166,
#   'median_forever': 240,
#   'name': 'Head Shot',
#   'negative': 793,
#   'owners': 552724,
#   'owners_variance': 23542,
#   'players_2weeks': 5771,
#   'players_2weeks_variance': 2407,
#   'players_forever': 426282,
#   'players_forever_variance': 20678,
#   'positive': 719,
#   'price': '199',
#   'publisher': 'Indie Game Group',
#   'score_rank': 7,
#   'userscore': 45},
#  '238590': {'appid': 238590,
#   'average_2weeks': 0,
#   'average_forever': 197,
#   'developer': '',
#   'median_2weeks': 0,
#   'median_forever': 28,
#   'name': 'Loadout Campaign Beta',
#   'negative': 0,
#   'owners': 565316,
#   'owners_variance': 23809,
#   'players_2weeks': 0,
#   'players_2weeks_variance': 0,
#   'players_forever': 252097,
#   'players_forever_variance': 15904,
#   'positive': 0,
#   'price': '0',
#   'publisher': '',
#   'score_rank': '',
#   'userscore': 0},
#  '11390': {'appid': 11390,
#   'average_2weeks': 17,
#   'average_forever': 105,
#   'developer': '',
#   'median_2weeks': 21,
#   'median_forever': 25,
#   'name': 'Crash Time 2',
#   'negative': 976,
#   'owners': 553774,
#   'owners_variance': 23565,
#   'players_2weeks': 1312,
#   'players_2weeks_variance': 1147,
#   'players_forever': 199894,
#   'players_forever_variance': 14163,
#   'positive': 1096,
#   'price': '999',
#   'publisher': 'Meridian4',
#   'score_rank': 10,
#   'userscore': 56},
#  '232790': {'appid': 232790,
#   'average_2weeks': 253,
#   'average_forever': 445,
#   'developer': 'Double Fine Productions',
#   'median_2weeks': 264,
#   'median_forever': 254,
#   'name': 'Broken Age',
#   'negative': 1004,
#   'owners': 592336,
#   'owners_variance': 24370,
#   'players_2weeks': 2886,
#   'players_2weeks_variance': 1702,
#   'players_forever': 358077,
#   'players_forever_variance': 18953,
#   'positive': 5092,
#   'price': '1999',
#   'publisher': 'Double Fine Productions',
#   'score_rank': 53,
#   'userscore': 81},
#  '263060': {'appid': 263060,
#   'average_2weeks': 159,
#   'average_forever': 380,
#   'developer': 'GhostShark',
#   'median_2weeks': 157,
#   'median_forever': 179,
#   'name': 'Blockstorm',
#   'negative': 1183,
#   'owners': 565054,
#   'owners_variance': 23803,
#   'players_2weeks': 6034,
#   'players_2weeks_variance': 2461,
#   'players_forever': 410805,
#   'players_forever_variance': 20299,
#   'positive': 5216,
#   'price': '499',
#   'publisher': 'IndieGala',
#   'score_rank': 49,
#   'userscore': 79},
#  '204180': {'appid': 204180,
#   'average_2weeks': 121,
#   'average_forever': 203,
#   'developer': 'Eden Industries',
#   'median_2weeks': 113,
#   'median_forever': 122,
#   'name': 'Waveform',
#   'negative': 332,
#   'owners': 593910,
#   'owners_variance': 24403,
#   'players_2weeks': 2099,
#   'players_2weeks_variance': 1451,
#   'players_forever': 382736,
#   'players_forever_variance': 19594,
#   'positive': 1754,
#   'price': '49',
#   'publisher': 'Eden Industries',
#   'score_rank': 56,
#   'userscore': 84},
#  '2600': {'appid': 2600,
#   'average_2weeks': 348,
#   'average_forever': 780,
#   'developer': 'Troika Games',
#   'median_2weeks': 58,
#   'median_forever': 178,
#   'name': 'Vampire: The Masquerade - Bloodlines',
#   'negative': 281,
#   'owners': 590762,
#   'owners_variance': 24338,
#   'players_2weeks': 6296,
#   'players_2weeks_variance': 2514,
#   'players_forever': 445432,
#   'players_forever_variance': 21137,
#   'positive': 5261,
#   'price': '1999',
#   'publisher': 'Activision',
#   'score_rank': 89,
#   'userscore': 94},
#  '462930': {'appid': 462930,
#   'average_2weeks': 332,
#   'average_forever': 527,
#   'developer': 'Hyper Hippo Games',
#   'median_2weeks': 42,
#   'median_forever': 40,
#   'name': 'AdVenture Communist',
#   'negative': 964,
#   'owners': 590499,
#   'owners_variance': 24333,
#   'players_2weeks': 19937,
#   'players_2weeks_variance': 4473,
#   'players_forever': 533312,
#   'players_forever_variance': 23126,
#   'positive': 2164,
#   'price': '0',
#   'publisher': 'Hyper Hippo Games',
#   'score_rank': 27,
#   'userscore': 69},
#  '288470': {'appid': 288470,
#   'average_2weeks': 186,
#   'average_forever': 672,
#   'developer': 'Lionhead Studios',
#   'median_2weeks': 47,
#   'median_forever': 278,
#   'name': 'Fable Anniversary',
#   'negative': 999,
#   'owners': 577121,
#   'owners_variance': 24056,
#   'players_2weeks': 10231,
#   'players_2weeks_variance': 3204,
#   'players_forever': 468779,
#   'players_forever_variance': 21683,
#   'positive': 3477,
#   'price': '3499',
#   'publisher': 'Microsoft',
#   'score_rank': 40,
#   'userscore': 76},
#  '105430': {'appid': 105430,
#   'average_2weeks': 191,
#   'average_forever': 2187,
#   'developer': '',
#   'median_2weeks': 29,
#   'median_forever': 331,
#   'name': 'Age of Empires Online',
#   'negative': 0,
#   'owners': 572399,
#   'owners_variance': 23957,
#   'players_2weeks': 3531,
#   'players_2weeks_variance': 2304,
#   'players_forever': 189138,
#   'players_forever_variance': 13777,
#   'positive': 0,
#   'price': '0',
#   'publisher': '',
#   'score_rank': '',
#   'userscore': 0},
#  '489220': {'appid': 489220,
#   'average_2weeks': 1012,
#   'average_forever': 511,
#   'developer': 'Amaterasu Software',
#   'median_2weeks': 306,
#   'median_forever': 271,
#   'name': 'Unforgiving Trials: The Darkest Crusade',
#   'negative': 82,
#   'owners': 556921,
#   'owners_variance': 23632,
#   'players_2weeks': 5771,
#   'players_2weeks_variance': 2407,
#   'players_forever': 413428,
#   'players_forever_variance': 20364,
#   'positive': 149,
#   'price': '99',
#   'publisher': 'Amaterasu Software',
#   'score_rank': 21,
#   'userscore': 60},
#  '457140': {'appid': 457140,
#   'average_2weeks': 505,
#   'average_forever': 1973,
#   'developer': 'Klei Entertainment',
#   'median_2weeks': 169,
#   'median_forever': 767,
#   'name': 'Oxygen Not Included',
#   'negative': 750,
#   'owners': 576858,
#   'owners_variance': 24050,
#   'players_2weeks': 110178,
#   'players_2weeks_variance': 10515,
#   'players_forever': 552200,
#   'players_forever_variance': 23531,
#   'positive': 7829,
#   'price': '2499',
#   'publisher': 'Klei Entertainment',
#   'score_rank': 78,
#   'userscore': 91},
#  ...}

# %% [markdown]
# Extract users' favorite game id and get id with the most played game.

# %%
dic_user_favorite_app = {}
dic_user_favorite_app_time = {}
with open(path_user_inventory, 'r') as f:
    for raw_string in f.readlines(): # Read each line in the file
        user_id, lst_inventory = list(json.loads(raw_string).items())[0] # Seperate userid&inventory
        if lst_inventory != None and lst_inventory != []:
#             Sort the most played game and extract game id in inventory
            most_played_app_id = sorted(lst_inventory, key=lambda k: k['playtime_forever'])[-1].get('appid')
            most_played_app_id_played_time = sorted(lst_inventory, key = lambda k:k['playtime_forever'])[-1].get('playtime_forever')
        else:
            most_played_app_id = None
        dic_user_favorite_app.update({user_id:most_played_app_id})
        dic_user_favorite_app_time.update({user_id:most_played_app_id_played_time})
        

# Transfter infomation to DF
df_user_favorite_app = pd.Series(dic_user_favorite_app).to_frame().reset_index()
df_user_favorite_app.columns = ['steam_user_id','most_played_app']

df_user_favorite_app_time = pd.Series(dic_user_favorite_app_time).to_frame().reset_index()
df_user_favorite_app_time.columns = ['steam_user_id','most_played_app_time']

# %%
df_user_favorite_app_time.head()
# Out:
#        steam_user_id  most_played_app_time
# 0  76561197960302536                 18670
# 1  76561197960323774                 81657
# 2  76561197960355015                 11736
# 3  76561197960385706                 13088
# 4  76561197960422789                 59357

# %%
df_user_favorite_app.head()
# Out:
#        steam_user_id  most_played_app
# 0  76561197960302536              NaN
# 1  76561197960323774              NaN
# 2  76561197960355015             10.0
# 3  76561197960385706         252950.0
# 4  76561197960422789            730.0

# %%
df_user_favorite_app.to_sql('tbl_user_favorite_app', engine, if_exists='replace', index=False)

# %% [markdown]
# Only choose the game and the initial price, release date is before today and has initial price.

# %%
# Read table from sql
df_steam_app = pd.read_sql('tbl_app_info',engine)
# choose those type is game, release_date <= today and has the price information
df_valid_games = df_steam_app.query('type == "game" and release_date <= "{}" and initial_price >= 0'.format(datetime.today().date().isoformat()))
# Extract the unique steam_appid from df
set_valid_game_id = set(df_valid_games.steam_appid)

# %%
df_valid_games.head()
# Out:
#    steam_appid                       name  type  initial_price release_date  \
# 0           10             Counter-Strike  game           9.99   2000-11-01
# 1           20      Team Fortress Classic  game           4.99   1999-04-01
# 2           30              Day of Defeat  game           4.99   2003-05-01
# 3           40         Deathmatch Classic  game           4.99   2001-06-01
# 4           50  Half-Life: Opposing Force  game           4.99   1999-11-01
#
#    score  recommendation  windows  mac  linux  \
# 0   88.0        117473.0      1.0  1.0    1.0
# 1    NaN          3653.0      1.0  1.0    1.0
# 2   79.0          3576.0      1.0  1.0    1.0
# 3    NaN          1439.0      1.0  1.0    1.0
# 4    NaN          4987.0      1.0  1.0    1.0
#
#                                         header_image
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Model 1 Popularity based

# %%
# list(dic_steamspy): all app IDs
# get(app id).get('owners'): how many owners for each game
dic_steamspy.get('570').get('owners')
# Out:
# 120750179

# %%
df_popularity_based_results = pd.Series([dic_steamspy.get(x).get('owners') for x in list(dic_steamspy)],list(dic_steamspy)).to_frame()
df_popularity_based_results.reset_index(inplace=True)
df_popularity_based_results.columns = ['steam_appid', 'owners']

# %%
df_popularity_based_results.to_sql('tbl_results_popularity_based',engine,if_exists='replace')

# %% [markdown]
# The most popular games

# %%
df_popularity_based_results.head()
# Out:
#   steam_appid     owners
# 0         570  120750179
# 1         440   44290079
# 2         730   39311626
# 3      304930   35011290
# 4      578080   27699958

# %%
top10games = [int(x) for x in list(df_popularity_based_results.head(11).steam_appid)]

# %%
df_steam_app[df_steam_app['steam_appid'].isin(top10games)]
# Out:
#        steam_appid                              name  type  initial_price  \
# 17             340           Half-Life 2: Lost Coast  game           0.00
# 23             440                   Team Fortress 2  game           0.00
# 25             550                     Left 4 Dead 2  game           9.99
# 26             570                            Dota 2  game           0.00
# 30             730  Counter-Strike: Global Offensive  game           0.00
# 4488        218620                          PAYDAY 2  game           9.99
# 4936        227940                 Heroes & Generals  game           0.00
# 4987        230410                          Warframe  game           0.00
# 15711       444090                         Paladins®  game           0.00
# 24748       578080     PLAYERUNKNOWN'S BATTLEGROUNDS  game          29.99
#
#       release_date  score  recommendation  windows  mac  linux  \
# 17      2005-10-27    NaN          6338.0      1.0  1.0    1.0
# 23      2007-10-10   92.0        521238.0      1.0  1.0    1.0
# 25      2009-11-16   89.0        237612.0      1.0  1.0    1.0
# 26      2013-07-09   90.0        920096.0      1.0  1.0    1.0
# 30      2012-08-21   83.0       2677551.0      1.0  1.0    1.0
# 4488    2013-08-13   79.0        348546.0      1.0  0.0    1.0
# 4936    2016-10-18    NaN         92545.0      1.0  0.0    0.0
# 4987    2013-03-25   71.0        198742.0      1.0  0.0    0.0
# 15711   2018-05-08   83.0        182062.0      1.0  1.0    0.0
# 24748   2017-12-21   86.0        865502.0      1.0  0.0    0.0
#
#                                             header_image
# 17     https://steamcdn-a.akamaihd.net/steam/apps/340...
# 23     https://steamcdn-a.akamaihd.net/steam/apps/440...
# 25     https://steamcdn-a.akamaihd.net/steam/apps/550...
# 26     https://steamcdn-a.akamaihd.net/steam/apps/570...
# 30     https://steamcdn-a.akamaihd.net/steam/apps/730...
# 4488   https://steamcdn-a.akamaihd.net/steam/apps/218...
# 4936   https://steamcdn-a.akamaihd.net/steam/apps/227...
# 4987   https://steamcdn-a.akamaihd.net/steam/apps/230...
# 15711  https://steamcdn-a.akamaihd.net/steam/apps/444...
# 24748  https://steamcdn-a.akamaihd.net/steam/apps/578...

# %% [markdown]
# ### Model 2 Content based - Description
#
# Find the most similar game based on description.

# %% [markdown]
# #### TfidfVectorizer - Term Frequency – Inverse Document Frequency
#
# TfidfVectorizer is the combination of countVectorizer and TfidfTransformer.
#
# countVectorizer:
#
# function generates a dictionary which counts the time frequency of each words.
# At the same time, use CountVectorizer().fit_transform(wordDictionary) to transfer frequency to metrix array.
#
#
# TfidfTransformer:
# Some words shows many times but are not meaningful. Some words shows only one time but are very important. We need TfidfTransformer to add weight on features so get a balance.

# %%
# all descriptions，without IDs
dic_about_the_game.values()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
# Intersect id in valid game and game id which has about_the_game description 
# Now, about_the_game only contains the valid game's id
for i in list(set(dic_about_the_game.keys()) - set(df_valid_games.steam_appid)):
    del dic_about_the_game[i]

#  TFIDF to transform values to matrix (frequency of weighted words)
tfidf = TfidfVectorizer(strip_accents='unicode',stop_words='english').fit_transform(list(dic_about_the_game.values()))
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
tfidf
# Out:
# <20793x113469 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1926757 stored elements in Compressed Sparse Row format>

# %%
# Have 20793 words
tfidf.shape
# Out:
# (20793, 113469)

# %% [markdown]
# #### Cosine similarity
# For cosine close to 1 (0 <= cosine <=1), then theta is more likely to be 0. The distance of A and B is shorter so that A is more similar to B.
#
# Here we use linear similarity which calculate faster than cosine similarity. Liner similarity has no range. When it is smaller, the two matrix are more similar.

# %%
cosine_similarities
# Out:
# array([0., 1., 0., ..., 0., 0., 9.])

# %%
print('Content Based Model')

# Find the similarity by the overlapping of words in each game's description
dic_recomended = {}
total_count = len(lst_app_id)
current_count = 0

lst_app_id = list(dic_about_the_game.keys())

# 22887 rows in tfidf
for index in range(tfidf.shape[0]):
#     Calculate the each description's similarity to the whole set
#     flatten() make sure all item in the same list
    cosine_similarities = linear_kernel(tfidf[index:index+1], tfidf).flatten()
#     There are 23 items in the list, sort the index of 23 items
    related_docs_indices = cosine_similarities.argsort()[-2:-22:-1]
#     Append the most similar ids to each id in dic_about_the_game, 
    dic_recomended.update({lst_app_id[index]:[lst_app_id[i] for i in related_docs_indices]})
    show_work_status(1,total_count,current_count)
    current_count+=1
# Out:
# Content Based Model
# Status: [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 100.00%

# %%
# Transfer result to dataframe
df_content_based_results = pd.DataFrame(dic_recomended).T
df_content_based_results.index.name = 'steam_appid'
df_content_based_results.reset_index(inplace=True)
df_content_based_results.to_sql('tbl_results_content_based',engine,if_exists='replace')

# %% [markdown]
# From the df we can see the most similar games for each app

# %%
df_content_based_results.head()
# Out:
#    steam_appid       0       1       2       3       4       5       6  \
# 0           10      20  887520  837940  207230  683600  222880  670270
# 1           20     440  393410  207230    2720  209270      10  485310
# 2           30     300  314770    4530  254960   34830  675950  502710
# 3           40  220440  414340  627670  286660  556780  786280  655200
# 4           50  362890     130  284080     220  634150     420  669490
#
#         7       8   ...        10     11      12      13      14      15  \
# 0  463920  743230   ...    344340  19830  246820  652660  504460  763430
# 1  511800   99300   ...    342660  65800  222940  707010  288710  426190
# 2  235380  258240   ...    342570  34600  532890  812930  593030  211780
# 3  454630  355090   ...    743350     60  661180  379720  895890  282440
# 4   10180  760560   ...    820460  22670  526250  670230  574500  856160
#
#        16      17      18      19
# 0  777850  803140    7940  843520
# 1  473810  803140  434510  416670
# 2  338130  616750  228200  303910
# 3     320  562010  413500  611500
# 4  601490  581300  655700  346300
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Model 3

# %% [markdown]
# ###### Item based
# Recommend product based on the similarity between products.

# %%
# Read the user inventory table

print('Item Based Model')

dic_purchase = {}
with open(path_user_inventory,'rb') as f:
    lst_all = f.readlines()
    total_count = len(lst_all)
    current_count = 0
    for i in lst_all:
#         json_loads transfer file to dict
#         items() retune a list of dicts
        user_id, user_inventory = list(json.loads(i).items())[0]
#         if user_inventory is not empty, set an empty dict for user_id 
        if user_inventory != [] and user_inventory != None and user_inventory != {}:
            dic_purchase[user_id] = {}
            for playtime_info in user_inventory:
                appid = playtime_info.get('appid') # Get all appid in user_inventory
                if appid in set_valid_game_id:
                    dic_purchase[user_id].update({appid:1}) # Update user_id and all app each user played
        show_work_status(1,total_count,current_count)
        current_count+=1
# Out:
# Item Based Model
# Status: [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 100.00%

# %%
# Set played game as 1 and unplayed game as 0
df_purchase = pd.DataFrame(dic_purchase).fillna(0)
purchase_matrix = df_purchase.values
lst_user_id = df_purchase.columns
lst_app_id = df_purchase.index

# %%
df_purchase.head()
# Out:
#     76561197960355015  76561197960385706  76561197960422789  \
# 10                1.0                1.0                1.0
# 20                1.0                1.0                1.0
# 30                1.0                1.0                1.0
# 40                1.0                1.0                1.0
# 50                1.0                1.0                1.0
#
#     76561197960464402  76561197960477514  76561197960562426  \
# 10                1.0                1.0                1.0
# 20                1.0                1.0                1.0
# 30                1.0                1.0                1.0
# 40                1.0                1.0                1.0
# 50                1.0                1.0                1.0
#
#     76561197960699459  76561197960893141  76561197961091730  \
# 10                1.0                1.0                1.0
# 20                1.0                1.0                1.0
# 30                1.0                1.0                1.0
# 40                1.0                1.0                1.0
# 50                1.0                1.0                1.0
#
#     76561197961243455        ...          76561198258604825  \
# 10                1.0        ...                        0.0
# 20                1.0        ...                        0.0
# 30                1.0        ...                        0.0
# 40                1.0        ...                        0.0
# 50                1.0        ...                        0.0
#
#     76561198258639801  76561198258679897  76561198258749191  \
# 10                1.0                0.0                0.0
# 20                0.0                0.0                0.0
# 30                0.0                0.0                0.0
# 40                0.0                0.0                0.0
# 50                0.0                0.0                0.0
#
#     76561198259586242  76561198259723921  76561198259865770  \
# 10                0.0                0.0                0.0
# 20                0.0                0.0                0.0
# 30                0.0                0.0                0.0
# 40                0.0                0.0                0.0
# 50                0.0                0.0                0.0
#
#     76561198259925540  76561198259974871  76561198260675813
# 10                0.0                0.0                0.0
# 20                0.0                0.0                0.0
# 30                0.0                0.0                0.0
# 40                0.0                0.0                0.0
# 50                0.0                0.0                0.0
#
# [5 rows x 4460 columns]

# %%
# Use linear kernel to calculate similarity of each row to all matrix 

dic_recomended_item_based = {}
total_count = purchase_matrix.shape[0]
current_count = 0

for index in range(total_count):
#     calculate similarity of each row to all matrix 
    cosine_similarities = linear_kernel(purchase_matrix[index:index+1], purchase_matrix).flatten()
#     take the negative number since we need the smallest as they are the most similar ones to target
    lst_related_app = (-cosine_similarities).argsort()[1:101]
#     Update dictionary with app id and the list of 100 most similar games
    dic_recomended_item_based.update({lst_app_id[index]:[lst_app_id[i] for i in lst_related_app]})
    show_work_status(1,total_count,current_count)
    current_count+=1

    

df_item_based_result = pd.DataFrame(dic_recomended_item_based).T
df_item_based_result.index.name = 'steam_appid'
df_item_based_result.reset_index(inplace=True)
df_item_based_result.to_sql('tbl_results_item_based',engine,if_exists='replace')
# Out:
# Status: [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 100.00%

# %%
lst_related_app
# Out:
# array([3166, 4123,  132,   22, 1399, 1477, 5387, 1567, 4476, 2817, 1867,
#        3330, 1340, 3152, 3455, 1540, 2816, 2264, 5469, 4782, 1076, 3019,
#        1471, 2420,  943, 3070, 5997, 2296, 1396, 1663, 1203, 3126,   20,
#        1284, 4990, 1041,   24, 2399, 1903, 1702, 3151, 3370, 3110, 1658,
#        1059, 1035, 2992, 1979, 1075, 1207, 5495, 2176, 1314, 3679, 3929,
#        2274, 2437, 1094, 1407, 1411, 1424, 5743, 2001, 2547, 4813,  482,
#        1800,  501,   14,   13,    9,   21,  296, 1458, 3390, 2436, 2888,
#         215, 4971, 1468,   16, 1616, 3969, 1473, 3039, 3897,  398,  412,
#         618, 1482, 4866, 4298, 3671,  554, 3577, 3572, 1754, 3880,  180,
#        6115])

# %%
df_item_based_result.head()
# Out:
#    steam_appid    0    1    2     3    4       5       6    7     8   ...    \
# 0           10  730   80  240  4000  550  304930  218620  340   620   ...
# 1           20   70   50  130   730  340     550     320  220  4000   ...
# 2           30   10  730   40    60  550     240     340  320  4000   ...
# 3           40   40   30   60   730  550     240     340  320    80   ...
# 4           50  130   70   20   730  550     340     320  220  4000   ...
#
#        90      91      92      93      94      95      96      97      98  \
# 0  238430  211820  200710  201790  236110   10090   40800    8980    4920
# 1   70000  220240  200510    9480  200260  273110  221910   17470  219150
# 2   10180  201790  291480  251570  207140   35720  211820    9480  236110
# 3   40800  251570  200260    9480  291480  211820   35720  236110  207140
# 4  273110  200510    9480   70000   17470  220240  219150  291480    4920
#
#        99
# 0  233720
# 1   35720
# 2    4920
# 3   35140
# 4   35720
#
# [5 rows x 101 columns]

# %% [markdown]
# ## Validation
#
# Since we cannot have the users data in the coming several months and it takes time to test whether the model is correct, here we extract some users and check if they played similar games as a validation.
#
# Now we have 3 tables of recommendation:
# * popularity_based_result
# * content_based_result
# * item_based_result
#
# Based on users'favorite game, we can make recommendation.

# %%
df_popularity_based_results.head()
# Out:
#   steam_appid     owners
# 0         570  120750179
# 1         440   44290079
# 2         730   39311626
# 3      304930   35011290
# 4      578080   27699958

# %%
df_content_based_results.head()
# Out:
#    steam_appid       0       1       2       3       4       5       6  \
# 0           10      20  887520  837940  207230  683600  222880  670270
# 1           20     440  393410  207230    2720  209270      10  485310
# 2           30     300  314770    4530  254960   34830  675950  502710
# 3           40  220440  414340  627670  286660  556780  786280  655200
# 4           50  362890     130  284080     220  634150     420  669490
#
#         7       8   ...        10     11      12      13      14      15  \
# 0  463920  743230   ...    344340  19830  246820  652660  504460  763430
# 1  511800   99300   ...    342660  65800  222940  707010  288710  426190
# 2  235380  258240   ...    342570  34600  532890  812930  593030  211780
# 3  454630  355090   ...    743350     60  661180  379720  895890  282440
# 4   10180  760560   ...    820460  22670  526250  670230  574500  856160
#
#        16      17      18      19
# 0  777850  803140    7940  843520
# 1  473810  803140  434510  416670
# 2  338130  616750  228200  303910
# 3     320  562010  413500  611500
# 4  601490  581300  655700  346300
#
# [5 rows x 21 columns]

# %%
df_item_based_result.head()
# Out:
#    steam_appid    0    1    2     3    4       5       6    7     8   ...    \
# 0           10  730   80  240  4000  550  352460  218620  340   620   ...
# 1           20   70   50  130   730  340     550     320  220  4000   ...
# 2           30   10  730   40    60  550     240     340  320  4000   ...
# 3           40   40   30   60   730  550     240     340  320    80   ...
# 4           50  130   70   20   730  550     340     320  220  4000   ...
#
#        90      91      92      93      94      95      96      97      98  \
# 0    4920  291550  209080   10180  251570  227300   70000  224600  223470
# 1  291480    4920   10090  251570  204300  228200  244850  201790   35140
# 2   35140   12120   10090  219150  220240  227300  200510  291550   17470
# 3    4920  220240   12120  200510   10090  219150   17470  227300  228200
# 4  200260   10090  221910   35140  244850  228200   22370  251570    4560
#
#        99
# 0  346900
# 1  227300
# 2  228200
# 3  207610
# 4  201790
#
# [5 rows x 101 columns]

# %%
# Game information
df_valid_games.head()
# Out:
#    steam_appid                       name  type  initial_price release_date  \
# 0           10             Counter-Strike  game           9.99   2000-11-01
# 1           20      Team Fortress Classic  game           4.99   1999-04-01
# 2           30              Day of Defeat  game           4.99   2003-05-01
# 3           40         Deathmatch Classic  game           4.99   2001-06-01
# 4           50  Half-Life: Opposing Force  game           4.99   1999-11-01
#
#    score  recommendation  windows  mac  linux  \
# 0   88.0        117473.0      1.0  1.0    1.0
# 1    NaN          3653.0      1.0  1.0    1.0
# 2   79.0          3576.0      1.0  1.0    1.0
# 3    NaN          1439.0      1.0  1.0    1.0
# 4    NaN          4987.0      1.0  1.0    1.0
#
#                                         header_image
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...

# %% [markdown]
# #### Test example
# For example, if the user 76561197960422789's most played game is 730 (Counter-Strike: Global Offensive, a shooter game), we recommend
#
# * Top 5 popular: Team Fortress 2, Dota 2, Counter-Strike: Global Offensive, Warframe, PLAYERUNKNOWN'S BATTLEGROUNDS
# * Content_based: Counter-Strike: Condition Zero, Counter-Strike: Source, Counter-Strike Nexon: Zombies, DARIUSBURST Chronicle Saviours
# * item_based: Left 4 Dead 2, Garry's Mod, PAYDAY 2, Warframe, Dead Realm
#
# We can from the example that people who play CS may be willing to play:
# * similar games like CS(other series) based on content-based recommendation
# * or other shooter games but with some cartoon or fantacy elements based on item-based recommendation
#
# Noted that the item-based recommendation also recommend games from popularity tables, which indicates that people are willing to give a try on the most popular games.
#
# Combining the three models together can avoid problems such as cold start(no data to make recommendation) and pigeon holes(keep recommending the similar games) so that increasing users loyalty to platform.

# %%
# Select the top 5 popular games
populartop5 = df_popularity_based_results['steam_appid'].iloc[0:6].values.flatten().tolist()
df_valid_games[df_valid_games['steam_appid'].isin(populartop5)]
# Out:
#        steam_appid                              name  type  initial_price  \
# 23             440                   Team Fortress 2  game           0.00
# 26             570                            Dota 2  game           0.00
# 30             730  Counter-Strike: Global Offensive  game           0.00
# 4987        230410                          Warframe  game           0.00
# 24748       578080     PLAYERUNKNOWN'S BATTLEGROUNDS  game          29.99
#
#       release_date  score  recommendation  windows  mac  linux  \
# 23      2007-10-10   92.0        521238.0      1.0  1.0    1.0
# 26      2013-07-09   90.0        920096.0      1.0  1.0    1.0
# 30      2012-08-21   83.0       2677551.0      1.0  1.0    1.0
# 4987    2013-03-25   71.0        198742.0      1.0  0.0    0.0
# 24748   2017-12-21   86.0        865502.0      1.0  0.0    0.0
#
#                                             header_image
# 23     https://steamcdn-a.akamaihd.net/steam/apps/440...
# 26     https://steamcdn-a.akamaihd.net/steam/apps/570...
# 30     https://steamcdn-a.akamaihd.net/steam/apps/730...
# 4987   https://steamcdn-a.akamaihd.net/steam/apps/230...
# 24748  https://steamcdn-a.akamaihd.net/steam/apps/578...

# %%
df_user_favorite_app.head(10)
# Out:
#        steam_user_id  most_played_app
# 0  76561197960302536              NaN
# 1  76561197960323774              NaN
# 2  76561197960355015             10.0
# 3  76561197960385706         252950.0
# 4  76561197960422789            730.0
# 5  76561197960464402            730.0
# 6  76561197960477514         346110.0
# 7  76561197960562426            620.0
# 8  76561197960699459         252490.0
# 9  76561197960893141            730.0

# %%
df_valid_games[df_valid_games['steam_appid'] == 730]
# Out:
#     steam_appid                              name  type  initial_price  \
# 30          730  Counter-Strike: Global Offensive  game            0.0
#
#    release_date  score  recommendation  windows  mac  linux  \
# 30   2012-08-21   83.0       2677551.0      1.0  1.0    1.0
#
#                                          header_image
# 30  https://steamcdn-a.akamaihd.net/steam/apps/730...

# %%
df_content_based_results[df_content_based_results['steam_appid'] == 730]
# Out:
#     steam_appid       0       1    2   3       4       5       6       7    8  \
# 25          730  377870  838900  240  80  273110  814480  525100  727790  500
#
#      ...        10      11    12      13      14      15      16   17      18  \
# 25   ...    479130  386740  3900  440280  220160  331650  773390  220  239820
#
#         19
# 25  882030
#
# [1 rows x 21 columns]

# %%
# Allocate the most similar games with app 730
simi730_content = df_content_based_results[df_content_based_results['steam_appid'] == 730].values.flatten().tolist()[1:6]
# We can see most the recommended game are from the same series or belongs to the same type.
df_valid_games[df_valid_games['steam_appid'].isin(simi730_content)]
# Out:
#        steam_appid                            name  type  initial_price  \
# 7               80  Counter-Strike: Condition Zero  game           9.99
# 13             240          Counter-Strike: Source  game           9.99
# 6532        273110   Counter-Strike Nexon: Zombies  game           0.00
# 11956       377870  DARIUSBURST Chronicle Saviours  game          49.99
# 44107       838900                     Cereal Soup  game           0.00
#
#       release_date  score  recommendation  windows  mac  linux  \
# 7       2004-03-01   65.0         12247.0      1.0  1.0    1.0
# 13      2004-11-01   88.0         74394.0      1.0  1.0    1.0
# 6532    2014-10-07    NaN         32983.0      1.0  0.0    0.0
# 11956   2015-12-03   80.0           415.0      1.0  0.0    0.0
# 44107   2018-06-02    NaN           316.0      1.0  0.0    0.0
#
#                                             header_image
# 7      https://steamcdn-a.akamaihd.net/steam/apps/80/...
# 13     https://steamcdn-a.akamaihd.net/steam/apps/240...
# 6532   https://steamcdn-a.akamaihd.net/steam/apps/273...
# 11956  https://steamcdn-a.akamaihd.net/steam/apps/377...
# 44107  https://steamcdn-a.akamaihd.net/steam/apps/838...

# %%
df_item_based_result[df_item_based_result['steam_appid'] == 730]
# Out:
#     steam_appid     0       1    2       3       4    5       6       7  \
# 22          730  4000  352460  550  218620  230410  240  105600  227940
#
#          8   ...        90     91   92      93      94     95      96      97  \
# 22  252950   ...    299360  48700  300  201790  223470  12120  200710  311210
#
#         98      99
# 22  274940  247730
#
# [1 rows x 101 columns]

# %%
# Allocate the most similar games with app 730
simi730_item = df_item_based_result[df_item_based_result['steam_appid'] == 730].values.flatten().tolist()[1:6]
# We can see most the recommended game are from the same type or the most popular games' table.
df_valid_games[df_valid_games['steam_appid'].isin(simi730_item)]
# Out:
#        steam_appid           name  type  initial_price release_date  score  \
# 25             550  Left 4 Dead 2  game           9.99   2009-11-16   89.0
# 256           4000    Garry's Mod  game           9.99   2006-11-29    NaN
# 4488        218620       PAYDAY 2  game           9.99   2013-08-13   79.0
# 4987        230410       Warframe  game           0.00   2013-03-25   71.0
# 10490       352460     Dead Realm  game          14.99   2017-05-23    NaN
#
#        recommendation  windows  mac  linux  \
# 25           237612.0      1.0  1.0    1.0
# 256          351217.0      1.0  1.0    1.0
# 4488         348546.0      1.0  0.0    1.0
# 4987         198742.0      1.0  0.0    0.0
# 10490          4631.0      1.0  1.0    0.0
#
#                                             header_image
# 25     https://steamcdn-a.akamaihd.net/steam/apps/550...
# 256    https://steamcdn-a.akamaihd.net/steam/apps/400...
# 4488   https://steamcdn-a.akamaihd.net/steam/apps/218...
# 4987   https://steamcdn-a.akamaihd.net/steam/apps/230...
# 10490  https://steamcdn-a.akamaihd.net/steam/apps/352...
